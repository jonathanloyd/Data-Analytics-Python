# %%
from pathlib import Path
from textblob import TextBlob
from operator import itemgetter
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from textatistic import Textatistic
import spacy
from collections import Counter

# %%
# For stopword analysis
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stopwords = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jloyd\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
"""Part 1
Select and download three texts of your choosing that represent different media or writing formats 
(for example, you could choose i. a novel, movie script, and play script or ii. a short story, poem, and novel, etc.) 
Make sure you briefly descibe your documents and explain the difference between them in a paragraph"""

# This will be in the report
# Out:
# 'Part 1\nSelect and download three texts of your choosing that represent different media or writing formats \n(for example, you could choose i. a novel, movie script, and play script or ii. a short story, poem, and novel, etc.) \nMake sure you briefly descibe your documents and explain the difference between them in a paragraph'

# %%
"""Part 2 a
Compute word counts for each of your documents after excluding English stop words (and optionally, performing lemmatization)."""

# Create Text blobs of the 3 texts
fear_blob = TextBlob(Path('fear_and_loathing_hunter_thompson_novel.txt').read_text())
machina_blob = TextBlob(Path('ex_machina_movie_script.txt').read_text())
tree_blob = TextBlob(Path('giving_tree_shel_silverstein_picture_book.txt').read_text())

# Get word counts of fear and loathing then remove stop words
fear_items = fear_blob.word_counts.items()
fear_items = [item for item in fear_items if item[0] not in stopwords]

# Get word counts of ex machina then remove stop words
machina_items = machina_blob.word_counts.items()
machina_items = [item for item in machina_items if item[0] not in stopwords]

# Get word counts of giving tree then remove stop words
tree_items = tree_blob.word_counts.items()
tree_items = [item for item in tree_items if item[0] not in stopwords]

# For displaying the frequencies uncomment these 3 print statements
# print(fear_items)
# print(machina_items)
# print(tree_items)

# %%
"""Part 2 b
Create and display a bar plot for each document that include word counts for the 25 most frequent words (after the above processing)."""

# Sort the items in descending order of frequency
fear_sorted_items = sorted(fear_items, key=itemgetter(1), reverse=True)
machina_sorted_items = sorted(machina_items, key=itemgetter(1), reverse=True)
tree_sorted_items = sorted(tree_items, key=itemgetter(1), reverse=True)

# Get the top 25 most frequent words and put them in a dataframe
fear_top25 = fear_sorted_items[:25]
fear_df = pd.DataFrame(fear_top25, columns=['word', 'count'])
machina_top25 = machina_sorted_items[:25]
machina_df = pd.DataFrame(machina_top25, columns=['word', 'count'])
tree_top25 = tree_sorted_items[:25]
tree_df = pd.DataFrame(tree_top25, columns=['word', 'count'])

# Plot and show the bar graphs
fear_df.plot.bar(x='word', y='count', legend=False)
plt.title("Fear and Loathing Word Frequencies")
plt.gcf().tight_layout()

machina_df.plot.bar(x='word', y='count', legend=False)
plt.title("Ex Machina Word Frequencies")
plt.gcf().tight_layout()

tree_df.plot.bar(x='word', y='count', legend=False)
plt.title("Giving Tree Word Frequencies")
plt.gcf().tight_layout()

# %%
"""Part 2 c
Create and display a word cloud for each document (using a mask image of your choice) that includes only the 100 most frequent words."""

# The items are already sorted so we can just get the top 100 of each text
fear_100_dict = {item[0]: item[1] for item in fear_sorted_items[:100]}
machina_100_dict = {item[0]: item[1] for item in machina_sorted_items[:100]}
tree_100_dict = {item[0]: item[1] for item in tree_sorted_items[:100]}

# Configure the wordclouds and show the 3 wordclouds
fear_wordcloud = WordCloud(width=1000, height=1000,
                     colormap='prism', background_color='white')
fear_wordcloud.fit_words(fear_100_dict)
plt.figure(figsize=(10,10))
plt.imshow(fear_wordcloud)

machina_wordcloud = WordCloud(width=1000, height=1000,
                     colormap='prism', background_color='white')
machina_wordcloud.fit_words(machina_100_dict)
plt.figure(figsize=(10,10))
plt.imshow(machina_wordcloud)

tree_wordcloud = WordCloud(width=1000, height=1000,
                     colormap='prism', background_color='white')
tree_wordcloud.fit_words(tree_100_dict)
plt.figure(figsize=(10,10))
plt.imshow(tree_wordcloud)

# %%
"""Part 2 d
Do you see any notable difference between the documents wrt (b) and/or (c) above? 
Try to explain why or why not, and whether you would expect such a difference."""

# This will be in the report
# Out:
# 'Part 2 d\nDo you see any notable difference between the documents wrt (b) and/or (c) above? \nTry to explain why or why not, and whether you would expect such a difference.'

# %%
"""Part 3 a
Use Textatistic to compute the average of the Flesch–Kincaid, Gunning Fog, SMOG, and Dale–Chall scores for each document."""

# Get the texts of all 3 pieces of media
fear_text = Path('fear_and_loathing_hunter_thompson_novel.txt').read_text()
machina_text = Path('ex_machina_movie_script.txt').read_text()
tree_text = Path('giving_tree_shel_silverstein_picture_book.txt').read_text()

# Get the readability through Textatistic objects
fear_readability = Textatistic(fear_text)
machina_readability = Textatistic(machina_text)
tree_readability = Textatistic(tree_text)

# Print out the readabilities
# NOTE: fleschkincaid_score==Flesch–Kincaid, gunningfog_score==Gunning Fog, smog_score==SMOG, and dalechall_score==Dale–Chall
print(f"Fear and Loathing Readability\n\tFlesch-Kincaid: {fear_readability.dict()['fleschkincaid_score']:.3f}",
     f"\n\tGunning Fog: {fear_readability.dict()['gunningfog_score']:.3f}",
     f"\n\tSMOG: {fear_readability.dict()['smog_score']:3f}",
     f"\n\tDale-Chall: {fear_readability.dict()['dalechall_score']:.3f}")
print(f"\nEx Machina Readability\n\tFlesch-Kincaid: {machina_readability.dict()['fleschkincaid_score']:.3f}",
     f"\n\tGunning Fog: {machina_readability.dict()['gunningfog_score']:.3f}",
     f"\n\tSMOG: {machina_readability.dict()['smog_score']:3f}",
     f"\n\tDale-Chall: {machina_readability.dict()['dalechall_score']:.3f}")
print(f"\nGiving Tree Readability\n\tFlesch-Kincaid: {tree_readability.dict()['fleschkincaid_score']:.3f}",
     f"\n\tGunning Fog: {tree_readability.dict()['gunningfog_score']:.3f}",
     f"\n\tSMOG: {tree_readability.dict()['smog_score']:3f}",
     f"\n\tDale-Chall: {tree_readability.dict()['dalechall_score']:.3f}")

# For printing out all parts of the readability
# print(fear_readability.dict())
# print(machina_readability.dict())
# print(tree_readability.dict())

# Calculate and print averages of the 4 scores
fear_avg_readability = fear_readability.dict()['fleschkincaid_score'] + fear_readability.dict()['gunningfog_score'] + fear_readability.dict()['smog_score'] + fear_readability.dict()['dalechall_score']
fear_avg_readability /= 4
machina_avg_readability = machina_readability.dict()['fleschkincaid_score'] + machina_readability.dict()['gunningfog_score'] + machina_readability.dict()['smog_score'] + machina_readability.dict()['dalechall_score']
machina_avg_readability /= 4
tree_avg_readability = tree_readability.dict()['fleschkincaid_score'] + tree_readability.dict()['gunningfog_score'] + tree_readability.dict()['smog_score'] + tree_readability.dict()['dalechall_score']
tree_avg_readability /= 4
print(f"\n\nFear and Loathing Average Readability: {fear_avg_readability:.3f}")
print(f"Ex Machina Average Readability: {machina_avg_readability:.3f}")
print(f"Giving Tree Average Readability: {tree_avg_readability:.3f}")
# Out:
# Fear and Loathing Readability
# 	Flesch-Kincaid: 2.236
# 	Gunning Fog: 5.153
# 	SMOG: 6.611695
# 	Dale-Chall: 6.750
#
# Ex Machina Readability
# 	Flesch-Kincaid: 1.175
# 	Gunning Fog: 4.084
# 	SMOG: 6.013996
# 	Dale-Chall: 7.750
#
# Giving Tree Readability
# 	Flesch-Kincaid: 0.405
# 	Gunning Fog: 3.784
# 	SMOG: 3.827023
# 	Dale-Chall: 0.689
#
#
# Fear and Loathing Average Readability: 5.188
# Ex Machina Average Readability: 4.756
# Giving Tree Average Readability: 2.176

# %%
"""Part 3 b
Are there noticeable differences among your documents's readability scores, and do you suspect any difference is present (or should be present)?"""

# This will be in the report
# Out:
# "Part 3 b\nAre there noticeable differences among your documents's readability scores, and do you suspect any difference is present (or should be present)?"

# %%
"""Part 4 a
Use spaCy to compute the pairwise similarity between your documents (i.e. doc. 1 to doc. 2, doc. 1 to doc. 3, doc. 2 to doc. 3)."""

# Load the large spacy nlp model for best accuracy
nlp_lg = spacy.load('en_core_web_lg')

# Create docs for the 3 pieces of media
fear_doc = nlp_lg(fear_text)
machina_doc = nlp_lg(machina_text)
tree_doc = nlp_lg(tree_text)

# Get the document similarities
fear_machina_docsim = fear_doc.similarity(machina_doc)
fear_tree_docsim = fear_doc.similarity(tree_doc)
machina_tree_docsim = machina_doc.similarity(tree_doc)

# Print out the document similarities
print(f"Fear and Loathing to Ex Machina similarity is {fear_machina_docsim:.4f}.",
     f"\nFear and Loathing to Giving tree similarity is {fear_tree_docsim:.4f}.",
     f"\nEx Machina to Giving Tree similarity is {fear_machina_docsim:.4f}.")
# Out:
# Fear and Loathing to Ex Machina similarity is 0.9853.
# Fear and Loathing to Giving tree similarity is 0.9869.
# Ex Machina to Giving Tree similarity is 0.9853.

# %%
"""Part 4 b
Do any of these similarity scores seem higher or lower than you would expect? Explain your response."""

# This will be in the report
# Out:
# 'Part 4 b\nDo any of these similarity scores seem higher or lower than you would expect? Explain your response.'

# %%
"""Part 5 a
Use spaCy to find the named entities in your documents."""

# Use .ents of the document objects to print out
# text entities and thier corresponding labels
print("Fear and Loathing Entities:")
for entity in fear_doc.ents:
    print(f'{entity.text}: {entity.label_}')
print("\n\nEx Machina Entities")
for entity in machina_doc.ents:
    print(f'{entity.text}: {entity.label_}')
print("\n\nGiving Tree Entities")
for entity in tree_doc.ents:
    print(f'{entity.text}: {entity.label_}')
# Out:
# Fear and Loathing Entities:
# Las Vegas: GPE
# Savage Journey To The Heart Of The American Dream
#
# : ORG
# Bob Geiger: PERSON
# Bob Dylan: PERSON
# Tambourine Man: PERSON
# Johnson
#
# : PERSON
# ONE: CARDINAL
# Barstow: GPE
# about a hundred miles: QUANTITY
# Las Vegas: GPE
# Spanish: NORP
# Red Shark: ORG
# almost noon: TIME
# more than a hundred miles: CARDINAL
# four: CARDINAL
# New York: GPE
# Chevy: ORG
# the Sunset Strip: LOC
# 300: MONEY
# two: CARDINAL
# seventy -
# : CARDINAL
# five: CARDINAL
# half: CARDINAL
# Budweiser: PRODUCT
# two dozen: CARDINAL
# the night before: TIME
# Los Angeles County: GPE
# Topanga: GPE
# Watts: GPE
# ninety miles: QUANTITY
# Barstow: GPE
# One: CARDINAL
# Sweet Jesus
# : PERSON
# One: CARDINAL
# One: CARDINAL
# Sympathy for the
# Devil: WORK_OF_ART
# Okie: PERSON
# Manson: PERSON
# Great Red Shark: FAC
# a hundred and ten or
# : CARDINAL
# Las Vegas: GPE
# the American Dream: ORG
# twenty - four hours ago: TIME
# the Polo Lounge: ORG
# Strip: LOC
# Samoan: NORP
# the Polo Lounge - for: ORG
# Singapore Slings: ORG
# Dwark: ORG
# Las
# Vegas: GPE
# Portuguese: NORP
# first: ORDINAL
# L.A.: GPE
# my weekend: DATE
# The Mint: WORK_OF_ART
# Del Webb: PERSON
# Mint Hotel: FAC
# Las Vegas: GPE
# New York: GPE
# Vincent Black Shadow: PERSON
# two hundred: CARDINAL
# four thousand
# : CARDINAL
# two: CARDINAL
# two hundred pounds: QUANTITY
# New York: GPE
# 2: CARDINAL
# 300: MONEY
# Beverly Hills: GPE
# New York: GPE
# Vincent Black Shadow: PERSON
# Los Angeles: GPE
# Beverly
# Hills: GPE
# the Polo Lounge: FAC
# more than $300: MONEY
# California: GPE
# 300: MONEY
# Samoans: NORP
# just one hour ago: TIME
# the weekend: DATE
# New York: GPE
# Las Vegas: GPE
# Beverly
# Hills: GPE
# 300: MONEY
# the American Dream: ORG
# first: ORDINAL
# Acapulco: GPE
# American: NORP
# Horatio Alger: PERSON
# Las Vegas: GPE
# Hollywood: GPE
# Las Vegas: GPE
# 6:30: TIME
# Friday: DATE
# afternoon: TIME
# Hollywood: GPE
# one: CARDINAL
# Polynesian: NORP
# seventeen: CARDINAL
# thirty minutes: TIME
# Belgian: NORP
# mike: PERSON
# about five miles: QUANTITY
# Stingray: PRODUCT
# Sunset Boulevard: FAC
# two: CARDINAL
# one: CARDINAL
# One: CARDINAL
# two - foot: QUANTITY
# Forty - five: CARDINAL
# the Pinto ~
# : GPE
# Las Vegas: GPE
# Reds: ORG
# Las Vegas: GPE
# Catholics: NORP
# Malibu: GPE
# Pasadena: GPE
# East: LOC
# 3: CARDINAL
# hitchhiker: WORK_OF_ART
# Farouk: PERSON
# Miami: GPE
# Las Vegas: GPE
# Strip: LOC
# Flamingo: ORG
# Americans: NORP
# four: CARDINAL
# two: CARDINAL
# one: CARDINAL
# Bass: PERSON
# Las Vegas: GPE
# Vegas: GPE
# Savage Henry: PERSON
# years: DATE
# Savage Henry: ORG
# Baker: PERSON
# a minute: TIME
# Shit: ORG
# hours: TIME
# a hundred miles: QUANTITY
# the Polo Lounge: ORG
# Mescal Springs: ORG
# Mint: ORG
# American: NORP
# the Great Samoan Dream: EVENT
# Las Vegas: GPE
# Power to the People - Right On: PRODUCT
# John Lennon's: PERSON
# ten
# years: DATE
# half: CARDINAL
# One: CARDINAL
# Colt Python: PRODUCT
# morning: TIME
# Las Vegas: GPE
# the Drug Bund: ORG
# Samoan: NORP
# Savage Henry: WORK_OF_ART
# Vegas: GPE
# 20: MONEY
# thirty more minutes: TIME
# Las Vegas: GPE
# Sahara: LOC
# Thunderbird: PRODUCT
# Thirty minutes: TIME
# the Mint Hotel: FAC
# Nevada State: GPE
# Carson
# City: GPE
# Joe Frazier: PERSON
# Seattle: GPE
# about four: CARDINAL
# Tim Leary: PERSON
# Eldridge Cleaver: ORG
# Algeria: GPE
# Bob Dylan: PERSON
# Greenwich Village: GPE
# Terminal Island: LOC
# Cassius/Ali: ORG
# Joe Frazier: PERSON
# Nixon: PERSON
# this foul year: DATE
# 1971: DATE
# those years: DATE
# Las Vegas: GPE
# the Great Red Shark: EVENT
# the Mint Hotel: FAC
# Raoul Duke: PERSON
# this Red Shark: LOC
# Strip: LOC
# Moray Eel: LOC
# Moray: NORP
# two: CARDINAL
# two: CARDINAL
# cuba: GPE
# twelfth: ORDINAL
# Lacerda: ORG
# Brazilian: NORP
# Savage Henry: PERSON
# Vincent Black Shadow: PERSON
# 4: CARDINAL
# A
# : DATE
# Saturday: DATE
# Evening: TIME
# Vegas: GPE
# four: CARDINAL
# four: CARDINAL
# nine: CARDINAL
# Vitamin C: WORK_OF_ART
# Shoot: WORK_OF_ART
# three minutes: TIME
# eight fifty: DATE
# thirty minutes: TIME
# the Laos Invasion - a: EVENT
# Pentagon: ORG
# Main Street: FAC
# mike: PERSON
# Las Vegas: GPE
# now: DATE
# Saturday: DATE
# night: TIME
# Las Vegas: GPE
# two: CARDINAL
# The Battle Hymn: WORK_OF_ART
# Rusty: PERSON
# Rusty: PERSON
# the Mint Gun Club: ORG
# One
# mile: QUANTITY
# two: CARDINAL
# about a dozen: CARDINAL
# Vegas: GPE
# about fifty yards: QUANTITY
# one: CARDINAL
# half: CARDINAL
# ten or: QUANTITY
# The Mint Gun Club: ORG
# about a hundred: CARDINAL
# tomorrow: DATE
# five
# seconds: TIME
# Husquavarnas: PERSON
# Swedish: NORP
# Yamahas: NORP
# a few: CARDINAL
# Maicos: PERSON
# Pursang: GPE
# Sportster: PRODUCT
# Great Red Shark: FAC
# first: ORDINAL
# four: CARDINAL
# five: CARDINAL
# Kamikaze: NORP
# Two: CARDINAL
# fifty: CARDINAL
# Danish: NORP
# Acapulco: GPE
# half: CARDINAL
# a minute: TIME
# 5.Covering the Story: WORK_OF_ART
# three long hours: TIME
# seven: CARDINAL
# koffee & donut: WORK_OF_ART
# all night: TIME
# Circus - Circus: ORG
# at least two hundred: CARDINAL
# eight - thirty: CARDINAL
# Harley - Davidson: ORG
# this - Saturday: DATE
# Sunday: DATE
# Last night: TIME
# Mint: ORG
# two: CARDINAL
# one: CARDINAL
# Las Vegas: GPE
# ten bucks: MONEY
# a long
# night: TIME
# Seven hours: TIME
# Vegas: GPE
# a minute: TIME
# Mint: ORG
# 400: CARDINAL
# the Super Bowl: EVENT
# Kentucky: GPE
# the Lower Oakland Roller Derby Finals: ORG
# Harley: PRODUCT
# one: CARDINAL
# Senzaman: PERSON
# two
# hours: TIME
# the national sporting press: ORG
# Las
# : GPE
# Vegas: GPE
# the Fourth Annual "Mint: EVENT
# Nevada: GPE
# morning: TIME
# Mint Gun Club: ORG
# about ten miles: QUANTITY
# Vegas: GPE
# last minute: TIME
# first: ORDINAL
# ten: CARDINAL
# nine: CARDINAL
# ten: CARDINAL
# first: ORDINAL
# 405 Husquavarna: MONEY
# a hundred and ninety: CARDINAL
# ten: CARDINAL
# every two minutes: TIME
# first: ORDINAL
# some two hundred
# yards: CARDINAL
# ten: CARDINAL
# the first hundred
# : DATE
# another hundred: CARDINAL
# the end of
# : DATE
# the next two days: DATE
# Fabulous Mint: WORK_OF_ART
# noon: TIME
# one hundred feet: QUANTITY
# The Ford Motor Company
# : ORG
# Bronco: PRODUCT
# an Agonizing Reappraisal: WORK_OF_ART
# Bronco: PRODUCT
# One: CARDINAL
# ten: CARDINAL
# every few minutes: TIME
# fifty - mile: QUANTITY
# another brutal hour: TIME
# around eleven: DATE
# two: CARDINAL
# San Diego: GPE
# Theycut: PERSON
# Americans: NORP
# American: NORP
# one: CARDINAL
# one: CARDINAL
# CBS News: ORG
# The Selling Of The Pentagon: WORK_OF_ART
# two: CARDINAL
# & scrub
# oak/cactus: ORG
# Total Coverage: ORG
# Joe: PERSON
# Joe: PERSON
# the night before: TIME
# Steve: PERSON
# Joe: PERSON
# FOrd: PERSON
# Joe: PERSON
# the Mint Gun Club: ORG
# 6: CARDINAL
# the Desert Inn: LOC
# Drug
# : PERSON
# the Circus Circus: ORG
# Saturday: DATE
# midnight: TIME
# Ford: ORG
# Bronco: PRODUCT
# Lacerda: PERSON
# Stopless: WORK_OF_ART
# Topless: ORG
# bush: PERSON
# L.A.: GPE
# L.A.: GPE
# Las Vegas: GPE
# Big Sur: GPE
# Lionel Olay: ORG
# Reno: GPE
# Carmel: GPE
# one month: DATE
# Mercedes: FAC
# Reno: GPE
# three: CARDINAL
# three: CARDINAL
# 15,000: MONEY
# the fourth weekend: DATE
# Monday: DATE
# morning: TIME
# Reno: GPE
# this weekend: DATE
# GM: ORG
# the next weekend: DATE
# Reno: GPE
# two: CARDINAL
# GM: ORG
# Monday: DATE
# morning: TIME
# Monterey: GPE
# Carmel: ORG
# 30,000: MONEY
# two months later: DATE
# one: CARDINAL
# Las Vegas: GPE
# Reno: GPE
# Vegas
# : ORG
# earth: LOC
# about a year ago: DATE
# Las Vegas: GPE
# NEVADA: GPE
# this Saturday: DATE
# one: CARDINAL
# the Great Red Shark: FAC
# the Landmark Hotel: FAC
# the Desert Inn: LOC
# Debbie Reynolds/Harry
# James: PERSON
# Hep: ORG
# Tropicana: ORG
# Guy Lombardo: PERSON
# the Blue Room: FAC
# Royal Canadians: ORG
# Dunes: ORG
# Thunderbird: PRODUCT
# Hacienda: ORG
# The Vegas Visitor: ORG
# Nickel Nick's Slot Arcade: ORG
# Twenty - nine cent: MONEY
# Two: CARDINAL
# Desert Inn: LOC
# five - dollar: MONEY
# Debbie: PERSON
# five bucks: MONEY
# the Desert Inn: LOC
# Bob Hope's: PERSON
# Frank Sinatra's: PERSON
# Spiro Agnew's: PERSON
# Debbie: PERSON
# L.A.: GPE
# Debbie Reynolds: PERSON
# Sergeant Pepper: WORK_OF_ART
# Harry James: PERSON
# Debbie: PERSON
# the Circus - Circus Casino: ORG
# un: ORG
# Irish: NORP
# the Circus - Circus: ORG
# two dollars: MONEY
# Rotarian: NORP
# Pope: PERSON
# Brinks: ORG
# Zeep: WORK_OF_ART
# Las Vegas: GPE
# Circus - Circus: ORG
# Saturday: DATE
# night: TIME
# Nazis: NORP
# Sixth: ORDINAL
# about four: CARDINAL
# Carazito Brothers: ORG
# four: CARDINAL
# Wolverines: ORG
# San Diego: GPE
# half: CARDINAL
# fourteen - year - old: DATE
# two: CARDINAL
# Polacks: PERSON
# Polacks: NORP
# spring: DATE
# three: CARDINAL
# three: CARDINAL
# Korean Kittens: PERSON
# twenty - four hours: TIME
# ten - foot: QUANTITY
# just 99$: MONEY
# two hundred feet
# : QUANTITY
# Las Vegas: GPE
# Ninety - nine cents: MONEY
# two hundred feet: QUANTITY
# the Mint Hotel: FAC
# half -
# : CARDINAL
# two hundred feet: QUANTITY
# tonight: TIME
# 1.98: MONEY
# the Circus - Circus: ORG
# Las Vegas: GPE
# twelve: CARDINAL
# The first hour: TIME
# the second hour: TIME
# the Merry -
# Go - Round Bar: FAC
# second: ORDINAL
# American: NORP
# Two: CARDINAL
# two: CARDINAL
# Tonight: TIME
# a few hours: TIME
# George Metesky: PERSON
# One more hour: TIME
# Carson City: GPE
# Twenty years: DATE
# the Red Shark: ORG
# Paranoid Terror: ORG
# the Aweful Specter: PERSON
# Mint: ORG
# two: CARDINAL
# Mint Hotel Room: FAC
# 1221: CARDINAL
# Lacerda: ORG
# Portuguese: NORP
# half: CARDINAL
# eighths: CARDINAL
# a
# few hours earlier: TIME
# Three: CARDINAL
# Five: CARDINAL
# The Vincent Black Shadow: WORK_OF_ART
# a minute: TIME
# one: CARDINAL
# Seven: CARDINAL
# Up to Eight: CARDINAL
# Nine: CARDINAL
# Quick!: WORK_OF_ART
# many hours later: TIME
# One: CARDINAL
# years: DATE
# twenty minutes: TIME
# Lacerda: ORG
# ken: PERSON
# these Mint Hotel: FAC
# Las Vegas: GPE
# 1850: DATE
# Dallas: GPE
# four - thirty
# : DATE
# Sunday: DATE
# morning: TIME
# American: NORP
# the Big Winner: WORK_OF_ART
# Vegas: GPE
# Silver City: GPE
# the Money Wheel: FAC
# Thomas Jefferson -
# : PERSON
# 2: MONEY
# LAS VEGAS: GPE
# 50,000: MONEY
# Del Webb's: GPE
# Mint Hotel: FAC
# a Life Special: WORK_OF_ART
# The Red Shark: ORG
# Fremont: GPE
# Gonzo: PERSON
# before morning: TIME
# Japanese: NORP
# Three Dog Night: WORK_OF_ART
# Joy to the World: WORK_OF_ART
# Lennon: PERSON
# Glenn Campbell: PERSON
# only half: CARDINAL
# next six hours: TIME
# tomorrow: DATE
# one: CARDINAL
# one hundred yards: QUANTITY
# White Rabbit: WORK_OF_ART
# two hours: TIME
# the White Rabbit: FAC
# the White Rabbit: ORG
# one: CARDINAL
# two hours: TIME
# just two hours: TIME
# tomorrow: DATE
# a very difficult day: DATE
# 45: MONEY
# 100: MONEY
# the Sawtooth National Bank: ORG
# seconds: TIME
# White Rabbit: WORK_OF_ART
# 440: CARDINAL
# ten seconds: TIME
# White Rabbit: WORK_OF_ART
# Vida Blue: PRODUCT
# Whit: PERSON
# AC: ORG
# Mace: PERSON
# Mace: PERSON
# Mace: PERSON
# Mace: FAC
# just a minute ago: TIME
# Mace: PERSON
# tomorrow: DATE
# "Don't: CARDINAL
# night: TIME
# Four hours: TIME
# Mace: PERSON
# Genius 'Round the Wand Stands Hand in Hand: WORK_OF_ART
# One: CARDINAL
# the Love Generation: WORK_OF_ART
# One: CARDINAL
# the Great San Francisco Acid
# Wave: EVENT
# nearly ten years: DATE
# Ginsberg: PERSON
# night: TIME
# 3700 feet: QUANTITY
# second: ORDINAL
# 32: MONEY
# another six months or so: DATE
# San Francisco: GPE
# one night: TIME
# The Fillmore Auditorium: WORK_OF_ART
# One: CARDINAL
# BOOM: ORG
# the Drug Explosion: LAW
# one night: TIME
# Matrix: ORG
# only half: CARDINAL
# first: ORDINAL
# first: ORDINAL
# Pendleton: GPE
# Kingston Trio: ORG
# Pendleton: GPE
# Las Vegas: GPE
# Five years
# later: DATE
# Six: CARDINAL
# Main Era: ORG
# San Francisco: GPE
# the middle sixties: DATE
# one: CARDINAL
# five or maybe: CARDINAL
# forty
# nights - or: DATE
# Fillmore: GPE
# the Bay
# Bridge: LOC
# a hundred miles: QUANTITY
# L. L. Bean: PERSON
# Butte: GPE
# Treasure Island: GPE
# Oakland: GPE
# Berkeley: GPE
# Richmond: GPE
# any
# hour: TIME
# Bay: LOC
# the Golden Gate: FAC
# 101: CARDINAL
# Los: GPE
# Altos: FAC
# La Honda: FAC
# less than five years later: DATE
# Las Vegas: GPE
# West: LOC
# 9: CARDINAL
# Sidney
# Zion: ORG
# American Express: ORG
# IRS: ORG
# between $29 and $36: MONEY
# forty - eight: DATE
# hours: TIME
# Monday: DATE
# evening: TIME
# L.A.: GPE
# 25: MONEY
# Las Vegas: GPE
# Zippo: PERSON
# 6.95: MONEY
# half - dollar: MONEY
# 5: MONEY
# 7.50: MONEY
# the Great Red Shark: EVENT
# Horatio Alger: PERSON
# one: CARDINAL
# first: ORDINAL
# Las Vegas: GPE
# about six hundred: CARDINAL
# Neutrogena: ORG
# us -: PERCENT
# Samoan: NORP
# Magnum: PRODUCT
# California Highway Patrol: ORG
# Magnum: PRODUCT
# Mescal Springs: LOC
# Calley: PERSON
# these days: DATE
# Malibu: GPE
# Samoan: NORP
# 158: CARDINAL
# half -
# : CARDINAL
# 1500 feet: QUANTITY
# second: ORDINAL
# about forty
# pounds: PERCENT
# Samoan: NORP
# the Great Red Shark: EVENT
# Las Vegas: GPE
# the next twenty - four hours: DATE
# weekly: DATE
# the Mint Hotel: ORG
# 50: MONEY
# two: CARDINAL
# two quarts: TIME
# fifth: ORDINAL
# Bacardi Anejo: ORG
# polish: NORP
# Las Vegas: GPE
# Army: ORG
# Las Vegas: GPE
# four in the morning -
# : TIME
# 75: MONEY
# forty - eight hours: TIME
# a fucking penny: MONEY
# first: ORDINAL
# the Las Vegas Sun: ORG
# a few hours earlier: TIME
# Saigon: GPE
# 5: MONEY
# BEAUTY'S DEATH
#
# An: ORG
# Diane Hamby: PERSON
# 19: DATE
# last
# week: DATE
# Clark County Coroner's: PERSON
# one: CARDINAL
# 24 - year - old: DATE
# WASHINGTON: GPE
# AP: ORG
# House Subcommittee: ORG
# 160: CARDINAL
# American: NORP
# GI: ORG
# last year - 40: DATE
# Vietnam: GPE
# Asia: LOC
# the Pacific Command: ORG
# Vietnam: GPE
# Laos: GPE
# Thailand: GPE
# Hong Kong: GPE
# Vietnam: GPE
# four: CARDINAL
# Washington: GPE
# D.C.: GPE
# Selective Service
# Headquarters: ORG
# "And: CARDINAL
# yesterday: DATE
# One: CARDINAL
# Army: ORG
# iid: ORG
# Chinese: NORP
# Asiatic: NORP
# FIVE: CARDINAL
# Las Vegas: GPE
# over 100,000: CARDINAL
# the Great Scorer: EVENT
# Muhammad Ali: PERSON
# the Supreme Court: ORG
# five years: DATE
# Viet: NORP
# Five years: DATE
# 10: CARDINAL
# Western Union Intervenes: ORG
# Heem: PERSON
# New Assignment: PERSON
# the Sports Desk: ORG
# the Police
#
# Suddenly: ORG
# DUKE: PERSON
# Duke: PERSON
# DUKE: PERSON
# Carson City: GPE
# three thousand miles: QUANTITY
# Nevada: GPE
# Thompson: PERSON
# Raoul Duke': PERSON
# thirty seconds: TIME
# S. THOMPSON
# : PERSON
# o RAOUL DUKE
# : PERSON
# 1850: CARDINAL
# HOTEL LAS VEGAS
#
# CALL ME: ORG
# TOMORROW: DATE
# VEGAS: GPE
# FOUR DAY: DATE
# 50 THOUSAND: CARDINAL
# URGENT: ORG
# Thompson: PERSON
# Shark: ORG
# Gonzo: PERSON
# Los Angeles: GPE
# About half: CARDINAL
# Heem: PERSON
# Heem: PERSON
# later this
# : TIME
# morning: TIME
# Thompson: ORG
# Western Union: ORG
# Thompson: PERSON
# L.A.: GPE
# Main Street: FAC
# L.A.: GPE
# another week: DATE
# Las Vegas: GPE
# Las Vegas Boulevard: FAC
# thirty miles: QUANTITY
# three: CARDINAL
# one: CARDINAL
# the National District Attorneys': ORG
# one Las Vegas Hotel: ORG
# L.A.: GPE
# Chevy: ORG
# Cadillac: ORG
# a thousand: CARDINAL
# America: GPE
# Las Vegas: GPE
# Caesar's: ORG
# Tom Jones: PERSON
# Coupe de Ville: LOC
# Dunes: ORG
# early
# morning: TIME
# Aaawww: PERSON
# Vegas: GPE
# Tuesday: DATE
# 9:00 A.M: TIME
# Wild Bill's Cafe: WORK_OF_ART
# Las Vegas: GPE
# only one: CARDINAL
# L.A.: GPE
# U.S.: GPE
# Baker: PERSON
# Barstow: GPE
# the Hollywood Freeway: FAC
# Freak Kingdom: GPE
# the next five or six hours: DATE
# Butte: GPE
# Tijauana: GPE
# Acapulco: GPE
# first: ORDINAL
# three days: DATE
# Wild Bill's: PRODUCT
# half: CARDINAL
# about two thousand feet: QUANTITY
# Lacerda: ORG
# the L.A. Times: ORG
# Mint: ORG
# Run: EVENT
# Lacerda: PERSON
# New York: GPE
# last night: TIME
# first: ORDINAL
# Wild Bill's Tavern: LOC
# Budweiser: PRODUCT
# Red Shark: FAC
# three hundred miles: QUANTITY
# Dwark: GPE
# the Polo Lounge: ORG
# morning: TIME
# Wild Bill's: LOC
# Toronto: GPE
# half: CARDINAL
# sixty and seventy hours: TIME
# Wild
# Bill's: PRODUCT
# at least two hours: TIME
# Needles: GPE
# Efrem Zimbalist: PERSON
# FBI: ORG
# Eagle: ORG
# Boulder: GPE
# Efrem: PERSON
# Mint: ORG
# Do Not Disturb: WORK_OF_ART
# 600: CARDINAL
# Neutrogena: ORG
# Malibu: GPE
# FBI: ORG
# This Great Red Shark: EVENT
# Neutrogena: ORG
# two: CARDINAL
# five: CARDINAL
# hours: TIME
# Christian: NORP
# six in the morning: TIME
# New
# York: ORG
# 120 miles: QUANTITY
# Death Valley: LOC
# 12: CARDINAL
# the California Highway Patrol: ORG
# Mano: PERSON
# Mano: ORG
# 61: CARDINAL
# Tuesday: DATE
# 12:30 P.M.: TIME
# Baker: PERSON
# California: GPE
# Ballantine Ale
# : ORG
# three: CARDINAL
# four
# days: DATE
# the next five years of summer: DATE
# mornings: TIME
# Carson City: GPE
# Kesey: ORG
# Bible: WORK_OF_ART
# Reality: ORG
# Kesey: PERSON
# two: CARDINAL
# the California Highway
# Patrol: LOC
# About five miles: QUANTITY
# CHP: ORG
# about a hundred or: CARDINAL
# CHP: ORG
# first: ORDINAL
# 120: CARDINAL
# one: CARDINAL
# Max Speed: WORK_OF_ART
# no less than a hundred miles: CARDINAL
# 180 - degree: QUANTITY
# first: ORDINAL
# first: ORDINAL
# Budweiser: PRODUCT
# one: CARDINAL
# Shark: ORG
# ten: CARDINAL
# Budweiser: PRODUCT
# Shit: ORG
# first: ORDINAL
# a few hours: TIME
# four nights: DATE
# twenty hours: TIME
# L.A.: GPE
# Death Valley: GPE
# Las Vegas: GPE
# Mint: ORG
# the "VIP Parking: ORG
# two
# days: DATE
# as of noon: TIME
# Baker: PERSON
# two -
# : CARDINAL
# two miles: QUANTITY
# Baker: PERSON
# L.A.: GPE
# Baker: PERSON
# Vegas: GPE
# two: CARDINAL
# CHP: ORG
# L.A.: GPE
# 1: CARDINAL
# Sinclair: ORG
# the Majestic Diner: ORG
# Malibu: GPE
# Baker: PERSON
# First: ORDINAL
# CHP: ORG
# Baker: PERSON
# Vegas: GPE
# the
# Flamingo: ORG
# the National District Attorneys': ORG
# Cadillac: ORG
# Flamingo: ORG
# the Great
# Magnet: EVENT
# Baker: PERSON
# first: ORDINAL
# CHP: ORG
# the Great Magnet: LOC
# Vegas: GPE
# CHP: ORG
# East: LOC
# West: LOC
# Vegas: GPE
# Flamingo: ORG
# Horatio
# Alger.: PERSON
# the Hardware Barn: FAC
# Ballantine Ale: ORG
# Newark: GPE
# San Francisco: GPE
# Las Vegas: GPE
# Vegas: GPE
# Scorpio: PRODUCT
# Ignoto county: GPE
# American: NORP
# Vegas: GPE
# Two: CARDINAL
# About 20 miles: QUANTITY
# Baker: PERSON
# Magnum: PRODUCT
# aztec: NORP
# Three: CARDINAL
# Three: CARDINAL
# Shark: ORG
# two or three miles: QUANTITY
# the Highway Patrol: FAC
# Duke: PERSON
# Duke
# : PERSON
# the minute: TIME
# Las Vegas: GPE
# the Neo -
# : ORG
# American Church: ORG
# Barstow: GPE
# years: DATE
# half -
# : CARDINAL
# coke: ORG
# six: CARDINAL
# four - day: DATE
# Vegas: GPE
# two quarts: TIME
# two fifths: CARDINAL
# Chivas Regal: PRODUCT
# Baptist: ORG
# 22: MONEY
# Romilar: ORG
# Aneuristic: ORG
# the first day: DATE
# Review - Journal: ORG
# one: CARDINAL
# UPI: ORG
# Friday: DATE
# Charles Innes: PERSON
# 25: DATE
# late Thursday: DATE
# Maryland General Hospital: ORG
# weeks: DATE
# Innes: ORG
# Innes: ORG
# Massachusetts: GPE
# Republican: NORP
# Thursday: DATE
# Innes: ORG
# Innes: PERSON
# Wednesday: DATE
# night: TIME
# Mercy Hospital: ORG
# one: CARDINAL
# Innes: ORG
# Parke - Davis: ORG
# 1963: DATE
# Parke -
# Davis: ORG
# more than 12: CARDINAL
# 14 hours: TIME
# LSD: ORG
# Innes: ORG
# last Saturday: DATE
# the day: DATE
# first: ORDINAL
# Wednesday night: TIME
# Innes: ORG
# 2: CARDINAL
# Another Day: DATE
# first: ORDINAL
# the Red Shark: LOC
# Vegas: GPE
# L.A.: GPE
# Death Valley: LOC
# 15: CARDINAL
# Baker: PERSON
# CHP: ORG
# L.A.: GPE
# the late afternoon: TIME
# Shark: LOC
# between two
# old: DATE
# Air Force: ORG
# about half a mile: QUANTITY
# dusk: TIME
# first: ORDINAL
# daily: DATE
# about two hours: TIME
# Bloody Marys: FAC
# L.A.: GPE
# about twenty hours: TIME
# Las Vegas: GPE
# the Red Shark: LOC
# Chevy: ORG
# Mercedes: ORG
# 600 Towne - Cruiser
# Specials: PRODUCT
# Nazi: NORP
# American: ORG
# Coupe de Ville: PRODUCT
# Ten: CARDINAL
# Caddy: ORG
# RedShark: ORG
# midnight: TIME
# California: GPE
# Big Computer: ORG
# Las Vegas: GPE
# 875: CARDINAL
# Number875: GPE
# 045: CARDINAL
# Cadillac: ORG
# St. Louis: GPE
# Raoul Duke: PERSON
# Five
# days: DATE
# 25: MONEY
# twenty - five cents: MONEY
# the next four days: DATE
# Las Vegas -
# : GPE
# Paradise Boulevard: FAC
# one: CARDINAL
# Vegas: GPE
# Charlie Manson: PERSON
# Sahara: LOC
# tomorrow: DATE
# morning: TIME
# one: CARDINAL
# Boulder: GPE
# Flamingo: ORG
# Caesar's: ORG
# the Drug
# Conference: ORG
# Dunes: ORG
# Flamingo: ORG
# Vegas: GPE
# plaid bermuda: ORG
# Arnie Palmer: PERSON
# Manson Family: PERSON
# the Final
# Stakeout: PRODUCT
# only about two hundred: CARDINAL
# Michigan: GPE
# Agnew: PERSON
# about three feet: QUANTITY
# the District Attorneys': ORG
# Moonlight Motel: PERSON
# Paradise Boulevard: FAC
# only sixteen: CARDINAL
# second: ORDINAL
# third: ORDINAL
# ten minutes: TIME
# Levis: PERSON
# Chuck Taylor: PERSON
# ten - peso: MONEY
# Acapulco: GPE
# about three days old: DATE
# Sandy Bull's: PERSON
# Saigon - mirror: FAC
# Cadillac: ORG
# half: CARDINAL
# Michigan: GPE
# 3: CARDINAL
# Lucy: PERSON
# a quart of
# : QUANTITY
# two fifths: CARDINAL
# Bacardi Anejo: ORG
# night: TIME
# Flamingo: ORG
# Playboy
# Club: ORG
# Something like nine: CARDINAL
# about twenty minutes: TIME
# Singapore Grey: ORG
# Walter
# Cronkite: PERSON
# the Drug Conference: LAW
# anessentially simpatico
# : PERSON
# Pigs: ORG
# Vegas: GPE
# Mini - Suite 1150: PRODUCT
# the Far Wing: LOC
# one: CARDINAL
# stark naked: PERSON
# Lucy: PERSON
# Lucy: PERSON
# Lucy: PERSON
# Lucy: PERSON
# Lucy: PERSON
# Lucy: PERSON
# Duke: PERSON
# Lucy: PERSON
# Oscar Bonavena: PERSON
# Mace: PERSON
# Lucy: PERSON
# first: ORDINAL
# forty or: CARDINAL
# fifty: CARDINAL
# Lucy: PERSON
# Barbra Streisand: PERSON
# Montana: GPE
# Kalispel.: WORK_OF_ART
# Fantastic: WORK_OF_ART
# Barbra: PERSON
# the Americana Hotel: ORG
# tonight: TIME
# Lucy: PERSON
# Mace: PERSON
# Lucy: PERSON
# one: CARDINAL
# Lucy: PERSON
# Shit: ORG
# fifth: ORDINAL
# six months: DATE
# fifty bucks
# : MONEY
# Bogart: PERSON
# about four: CARDINAL
# three: CARDINAL
# about fifty feet: QUANTITY
# Lucy: PERSON
# Lucy: PERSON
# Nazi: NORP
# a few hours: TIME
# Los Angeles: GPE
# International Airport: FAC
# Samoan: NORP
# fed: ORG
# LSD: ORG
# Vegas: GPE
# Lucy: PERSON
# Barbra Strei - sand's: PERSON
# Americana: NORP
# thisbrutal: ORG
# Lucy: PERSON
# Lucy: PERSON
# Barbra Streisand: PERSON
# The Vegas Vistitor: GPE
# Streisand: PERSON
# Americana: NORP
# another three weeks: DATE
# Lucy: PERSON
# Mann Act: PERSON
# Samoan: NORP
# Southern California: LOC
# Chessman: PERSON
# Nevada: GPE
# Fatty Arbuckle: PERSON
# Vegas: GPE
# one: CARDINAL
# these days: DATE
# Lucy: PERSON
# Barbra: PERSON
# Martin Bormann: PERSON
# White: PERSON
# Darwin: PERSON
# Darwin: PERSON
# LSD: ORG
# Lucy: PERSON
# Lucy
# : PERSON
# two more days: DATE
# Lucy: PERSON
# At least $200: MONEY
# Montana: GPE
# Vegas: GPE
# First: ORDINAL
# Lucy: PERSON
# Lucy: PERSON
# about ten yards: QUANTITY
# Vegas: GPE
# Mercedes: ORG
# 600: PRODUCT
# Ten minutes: TIME
# Las Vegas Boulevard: FAC
# 10: MONEY
# five bucks: MONEY
# two: CARDINAL
# Kristofferson: PERSON
# Coupe de Ville: LOC
# tonight: TIME
# the
# Tropicana: ORG
# first: ORDINAL
# 4: CARDINAL
# Muderous Junkie
#
# We: ORG
# Flamingo: ORG
# Duke: PERSON
# two: CARDINAL
# One: CARDINAL
# Las Vegas: GPE
# Lucy: PERSON
# 1000: CARDINAL
# Othello: PERSON
# a few hours: TIME
# a little less
# : MONEY
# Rolaids: ORG
# Othello: ORG
# Dramamine: PRODUCT
# Fatty Arbuckle
# : PERSON
# Lucy: PERSON
# Duke: PERSON
# Duke: PERSON
# a moment ago: TIME
# spring: DATE
# Vietnam: GPE
# the Police
# Convention: LAW
# Duke: PERSON
# Duke: PERSON
# Chivas Regal: PRODUCT
# three hours: TIME
# 3000 watt: PERCENT
# Lucy: PERSON
# Americana: NORP
# one: CARDINAL
# Walt: PERSON
# a minute: TIME
# Chivas Regal: PRODUCT
# Baker: PERSON
# 35 bucks: MONEY
# a hundred and ninety
# goddamn: CARDINAL
# Pasadena: GPE
# three weeks: DATE
# six: CARDINAL
# Six: CARDINAL
# the Holiday Inn: FAC
# Ventura: GPE
# Lucy: PERSON
# Pit Bull: ORG
# eighteenth: ORDINAL
# at least
# : DATE
# twenty years: DATE
# two: CARDINAL
# LSD: ORG
# Lucy: PERSON
# the District At torney's: LOC
# Lucy: PERSON
# Squane: PERSON
# Lake Mead: LOC
# One: CARDINAL
# Los Angeles: GPE
# one: CARDINAL
# LSD: ORG
# Walter Cronkite: PERSON
# $2.95
# : MONEY
# 5: MONEY
# no less than nine
# : PERCENT
# six: CARDINAL
# Exhibit Z: ORG
# three: CARDINAL
# the National District Attorneys': ORG
# United States: GPE
# 5: CARDINAL
# Americana: NORP
# 1600: CARDINAL
# Lucy: PERSON
# Lucy: PERSON
# Tropicana: ORG
# two hours: TIME
# the Circus-Circus
# : ORG
# 0: CARDINAL
# Montana: GPE
# Lucy: PERSON
# Lucy: PERSON
# Mission
# Impossible: PRODUCT
# Adrenochrome: ORG
# first: ORDINAL
# wolf: PERSON
# Melvin Belli: PERSON
# 220: CARDINAL
# One: CARDINAL
# about a hundred pounds: QUANTITY
# two hours: TIME
# six: CARDINAL
# Last Christmas: DATE
# two: CARDINAL
# thiung: PERSON
# about twenty minutes: TIME
# Jimson: WORK_OF_ART
# three days: DATE
# Fantastic: ORG
# first: ORDINAL
# a few seconds: TIME
# Nixon: PERSON
# 220: CARDINAL
# more than two: CARDINAL
# three seconds: TIME
# one: CARDINAL
# Sunday: DATE
# Process: ORG
# London: GPE
# Call Inspector Bloor: WORK_OF_ART
# the crab looey: ORG
# Christian Brothers: ORG
# about twenty bucks: MONEY
# Reno: GPE
# about four hundred miles: QUANTITY
# Army: ORG
# The Big Flip: WORK_OF_ART
# New York: GPE
# 1.88: MONEY
# the "Coyote Bush Basket: ORG
# 2.09: MONEY
# four: CARDINAL
# eighty hours: TIME
# tomorrow: DATE
# noon: TIME
# British: NORP
# 6: CARDINAL
# Opening Day: DATE
# the Drug Convention
#
# : LAW
# about 1500: CARDINAL
# the Dunes Hotel: ORG
# the National District Attorneys'
# Association - a middle-: ORG
# GOP: ORG
# Pat rick Healy-: PERSON
# Third: ORDINAL
# National Institute on
# Narcotics and Dangerous Drugs: ORG
# dozen: CARDINAL
# Lroom: ORG
# This 1935: DATE
# Sheriff: ORG
# Muskogee: GPE
# ten: CARDINAL
# A year earlier: DATE
# the Sky River Rock Festival: LOC
# Washington: GPE
# dozen: CARDINAL
# the Seattle Liberation
# Front: ORG
# a half mile
# : QUANTITY
# the National DAs': LAW
# Vegas: GPE
# Ulysses S. Grant: PERSON
# the Seige of Vicksburg: ORG
# the Drug Culture: ORG
# Bloomquist: PERSON
# six months: DATE
# E. R. Bloomquist: PERSON
# MD: GPE
# one: CARDINAL
# Marijuana: PERSON
# Surgery: PERSON
# the University of Southern Cllfcruia School of
# Medicine": ORG
# Bllomquist: PERSON
# national network television: ORG
# the Committee on Narcotics Addiction and Alcoholism of the Council
# : ORG
# Mental Health: ORG
# the American Medical Association: ORG
# one: CARDINAL
# second: ORDINAL
# $500 to $1000: MONEY
# Bloomquist: PERSON
# 49: CARDINAL
# four: CARDINAL
# Bloomquist: PERSON
# Bloomquist: PERSON
# Tim Leary: PERSON
# Leary: PERSON
# Police Department: ORG
# The Dope Fiend: PERSON
# One: CARDINAL
# nine: CARDINAL
# Las Vegas: GPE
# this Drug Conference: EVENT
# About a third: CARDINAL
# Frazier-Ali: PERSON
# the Vegas Convention Center: EVENT
# Old Smack Dealers: ORG
# Liston: PERSON
# Ky.: GPE
# Mod: GPE
# Chicago: GPE
# Dunes: ORG
# Grace Slick: PERSON
# Finch College: ORG
# these days: DATE
# FBI: ORG
# Pat Boone: PERSON
# about twenty: CARDINAL
# Mississippi State: ORG
# Californians: NORP
# Middle America: LOC
# hundreds: CARDINAL
# thousand: CARDINAL
# 100: MONEY
# L.A.: GPE
# first: ORDINAL
# the first two hours: TIME
# hour after hour: TIME
# 344-pound: QUANTITY
# Waco: GPE
# Texas: GPE
# 290-pound: QUANTITY
# a Dope Film: PERSON
# two: CARDINAL
# thousand: CARDINAL
# Downers: Reds: ORG
# Grass: PERSON
# 1964: DATE
# more than a thousand: CARDINAL
# Mafia: ORG
# one: CARDINAL
# Bboomquist: ORG
# Margaret Mead's: PERSON
# Bboomquist: PERSON
# Bloomquist: PERSON
# first: ORDINAL
# about forty-five seconds: TIME
# about forty: CARDINAL
# Georgia: GPE
# One: CARDINAL
# Georgia: GPE
# California: GPE
# Bowie: PERSON
# L.A.: GPE
# First: ORDINAL
# Malibu: GPE
# six or eight: CARDINAL
# every day: DATE
# McDonald: ORG
# About six: CARDINAL
# years old: DATE
# Georgia: GPE
# six-seven: CARDINAL
# three hundred pounds: QUANTITY
# two: CARDINAL
# Lugers: ORG
# M-16s: ORG
# Marines: NORP
# Marines: NORP
# every day: DATE
# the night: TIME
# Three: CARDINAL
# Georgia: GPE
# Only
# : CARDINAL
# two: CARDINAL
# Georgia: GPE
# California: GPE
# Atlanta: GPE
# California: GPE
# Manson: PERSON
# the middle of
# Death Valley: DATE
# Georgia: GPE
# California: GPE
# Q.T.: WORK_OF_ART
# 8: CARDINAL
# Strip: LOC
# Ford: ORG
# Oklahoma: GPE
# two: CARDINAL
# Muskogee: GPE
# the Drug Conference: LAW
# Vegas: GPE
# Caesar's: ORG
# about $38: MONEY
# the Circus-Circus: ORG
# Cadillac: ORG
# 300-pound: QUANTITY
# Samoan: NORP
# four: CARDINAL
# Veet Naam: ORG
# Ford: ORG
# Communist: NORP
# Circus-Circus: ORG
# Oklahoma: GPE
# Ford: ORG
# two: CARDINAL
# Ford: ORG
# Ford: ORG
# three: CARDINAL
# Ford: ORG
# the Desert Inn: LOC
# Shit: PERSON
# Oklahoma Ford: ORG
# two: CARDINAL
# Cadillac: ORG
# Strip: LOC
# Sonny Liston: PERSON
# The Coupe de Ville
# : ORG
# the Red Shark: ORG
# four: CARDINAL
# first: ORDINAL
# Texaco: ORG
# Flamingo: ORG
# fifty pounds: QUANTITY
# fifty pounds: QUANTITY
# a few
# hours: TIME
# seventy five: CARDINAL
# seventy-five: CARDINAL
# twenty eight: CARDINAL
# thirty two: CARDINAL
# fifty: CARDINAL
# seventy five: CARDINAL
# Sandoz: ORG
# up to a hundred: CARDINAL
# today: DATE
# seventy-five: CARDINAL
# two: CARDINAL
# Cadillac: ORG
# four: CARDINAL
# 80: MONEY
# four: CARDINAL
# Eldorado: EVENT
# next time: DATE
# four: CARDINAL
# Michelin Xs: ORG
# the St Louis Browns: ORG
# one: CARDINAL
# ZANG: PERSON
# About thirty minutes: TIME
# Tonopah: FAC
# North Las Vegas: GPE
# Vegas: GPE
# North Vegas: GPE
# Strip: LOC
# Casino Center: FAC
# Nevada: GPE
# East St. Louis: GPE
# Ely: PERSON
# Winnemuca: PERSON
# North Vegas: GPE
# Strip: LOC
# Vegas: GPE
# Caesar's Palace: ORG
# a third: CARDINAL
# Secret Service: ORG
# two: CARDINAL
# Vegas: GPE
# Lucky Luciano: PERSON
# Howard
# Hughes: ORG
# Tom Jones: PERSON
# 75,000: MONEY
# two: CARDINAL
# Caeser's: ORG
# Vegas: GPE
# Vegas: GPE
# Strip: LOC
# North Vegas: GPE
# North Vegas: GPE
# midnight: TIME
# Strip: LOC
# at least one: CARDINAL
# Vegas: GPE
# Cadillac: ORG
# Fillmore: PERSON
# Sinatra: PERSON
# Dean Martin: PERSON
# Vegas: GPE
# the Las Vegas Free Press -
# : ORG
# The People's World: ORG
# the National Guardian: ORG
# Vegas: GPE
# Time Warp: ORG
# late fifties: DATE
# the Big Spenders: ORG
# Denver: GPE
# Dallas: GPE
# National Elks Club: ORG
# the All-West
# : LAW
# Sheepherders': ORG
# a dozen: CARDINAL
# 50-year-old: DATE
# September Song: WORK_OF_ART
# North Vegas: GPE
# the Los Angeles Times: ORG
# Times: ORG
# North Vegas: GPE
# the Vegas Sun: ORG
# yesterday: DATE
# the Sports
# Section: ORG
# Bart Starr: PERSON
# Thugs: ORG
# Chicago Tavern: ORG
# Packers Seek Trade: ORG
# Namath: PERSON
# Alabama: GPE
# 46: DATE
# Harrison Fire: PERSON
# Grambling: GPE
# the hundred in nine: CARDINAL
# 344 pounds: QUANTITY
# Yesterday: DATE
# a Greyhound Bus: FAC
# last night: TIME
# nine: CARDINAL
# this night: TIME
# the North Star Coffee Lounge: ORG
# two: CARDINAL
# The North Star Coffee Lounge: ORG
# the North Star: LOC
# Jane Russell: PERSON
# 48: CARDINAL
# about twenty years ago: DATE
# Berdoo: GPE
# tonight: TIME
# 29 cent: MONEY
# two: CARDINAL
# About ten minutes later: TIME
# hamburg: GPE
# ten feet: QUANTITY
# Back Door Beauty: WORK_OF_ART
# about six feet: QUANTITY
# Thirty five cents: MONEY
# five dollars: MONEY
# 9: CARDINAL
# Paradice Blvd: GPE
# Duke: PERSON
# Duke: PERSON
# Highway 61 - and: FAC
# Duke: ORG
# Duke: PERSON
# North Vegas: GPE
# Duke: PERSON
# American Dream: WORK_OF_ART
# District Attorneys': ORG
# Northeast: LOC
# Las Vegas -
# : GPE
# Paradise Road: FAC
# the White Whale: LOC
# Boulder City: GPE
# Boulder City: GPE
# Terry: PERSON
# Taco Stand: ORG
# USA: GPE
# Five: CARDINAL
# one: CARDINAL
# 5O cents: MONEY
# Five: CARDINAL
# five: CARDINAL
# Att'y: PERSON
# 29 cents: MONEY
# 29 cents: MONEY
# Mexican: NORP
# just regular
# : MONEY
# Mexican: NORP
# Lou: PERSON
# Mexican: NORP
# Authentic: NORP
# Mexican: NORP
# Lou: PERSON
# Mexican: NORP
# five: CARDINAL
# five: CARDINAL
# Taco burger: ORG
# Today: DATE
# one: CARDINAL
# taco burger: ORG
# two: CARDINAL
# Boulder City: GPE
# Boulder City: GPE
# Boulder City: GPE
# Boulder City: GPE
# Nevada: GPE
# Boulder City: GPE
# a minute: TIME
# New York: GPE
# a day: DATE
# the American Dream: ORG
# San Francisco: GPE
# Cadillac: ORG
# Lou: PERSON
# the American Dream: ORG
# Att'y: PERSON
# Duke: ORG
# American: NORP
# Five: CARDINAL
# one: CARDINAL
# taco burger: ORG
# Francisco: GPE
# the American Dream: ORG
# Lou: PERSON
# the American Dream: ORG
# Lou: PERSON
# Psychiatrist's Club: ORG
# Psychiatrist's Club: ORG
# Lou: PERSON
# Psychiatrist's Club: ORG
# Paradise: LOC
# Lou: PERSON
# Psychiatrist's Club: ORG
# Paradise: LOC
# Lou: PERSON
# Ross Allen: PERSON
# Psychiatrist's Club: ORG
# American: NORP
# Cadillac: ORG
# American: NORP
# the Las Vegas: GPE
# Lou: PERSON
# Lou: PERSON
# Lou: PERSON
# Lou: PERSON
# Thas: PERSON
# Psychiatrist's Club: ORG
# Lou: PERSON
# Lou: PERSON
# Paradise: LOC
# Psychiatrist's Club's: ORG
# Paradise: LOC
# Psychiatrist's Club: ORG
# Lou: PERSON
# American: NORP
# Lou: PERSON
# the American Dream: ORG
# more or less: CARDINAL
# Lou: PERSON
# Paradise: LOC
# Eastern: ORG
# Paradise: LOC
# Eastern: ORG
# Lou: PERSON
# Eastern: ORG
# Paradise: LOC
# Flamingo: ORG
# Flamingo: ORG
# Lou: PERSON
# Lou: PERSON
# Twenty-four: CARDINAL
# Lou: PERSON
# first: ORDINAL
# Tropicana: ORG
# Tropicana: ORG
# Lou: PERSON
# first: ORDINAL
# Tropicana: ORG
# Tropicana: ORG
# Tropicana: ORG
# Paradice: GPE
# Tropicana: ORG
# Paradise: LOC
# Lou: PERSON
# Psychiatrist's Club: ORG
# two days: DATE
# Lou: PERSON
# Lou: PERSON
# Allen: PERSON
# Tropicana: ORG
# first: ORDINAL
# second: ORDINAL
# Lou: PERSON
# Tropicana
# Avenue: ORG
# Paradice: GPE
# Paradise: LOC
# twenty-four: CARDINAL
# Tropicana: ORG
# Boulder Highway: FAC
# Boulder
# Highway: ORG
# Tropicana: ORG
# Lou: PERSON
# Lou: PERSON
# almost two hours: TIME
# Dr.
# Duke: PERSON
# Old
# Psychiatrist's: WORK_OF_ART
# Club"-a: PERSON
# about three years ago: DATE
# 10: CARDINAL
# Heavy Duty: ORG
# Peruvian: NORP
# first: ORDINAL
# LA: GPE
# less than thirty minutes: TIME
# Tropicana: ORG
# Peru: GPE
# Bolivian: NORP
# 707: CARDINAL
# five: CARDINAL
# six: CARDINAL
# about two hours later: TIME
# Lima: GPE
# one: CARDINAL
# half-moon: QUANTITY
# first: ORDINAL
# the next morning: TIME
# only half: CARDINAL
# Peru: GPE
# five miles: QUANTITY
# only one: CARDINAL
# two: CARDINAL
# a few hundred yards: QUANTITY
# about 60 miles: QUANTITY
# DC-8: ORG
# Accutron: ORG
# three minutes
# and: TIME
# fifteen seconds: TIME
# Western: NORP
# about 1000 yards: QUANTITY
# Cadillac: ORG
# Vegas: GPE
# Samoans: NORP
# the early
# morning: TIME
# Paradise Road: FAC
# Russell: PERSON
# Maryland: GPE
# anonym ity: ORG
# the University of Las Vegas: ORG
# Caddy
# : PRODUCT
# Flamingo: ORG
# Flamingo Road: FAC
# Vegas: GPE
# the Police Conference: ORG
# Las Vegas: GPE
# One: CARDINAL
# Vegas: GPE
# about twenty years old: DATE
# Levi: ORG
# the
# Sixties: DATE
# Bob Zimmerman: PERSON
# Chicago: GPE
# L.A.: GPE
# Vegas: GPE
# Strip: LOC
# the Circus Circus: ORG
# about six feet: QUANTITY
# dozen: CARDINAL
# about ten: CARDINAL
# the middle of: DATE
# about twenty bucks: MONEY
# twenty-five: DATE
# two: CARDINAL
# 130,000: MONEY
# two: CARDINAL
# a hundred bucks: MONEY
# about twenty minutes: TIME
# one: CARDINAL
# Chicago: GPE
# About two hours: TIME
# One: CARDINAL
# 30,000: MONEY
# 125
# bucks: MONEY
# seven or eight days: DATE
# twelve hours: TIME
# seventy-five: CARDINAL
# thirty years: DATE
# another twenty-five
# bucks: DATE
# 75: MONEY
# Nevada: GPE
# one: CARDINAL
# 11: CARDINAL
# Alice: PERSON
# the White Whale: LOC
# Fifty
# bucks: MONEY
# a week: DATE
# Larceny: PERSON
# Sports Illustrated: PERSON
# years: DATE
# Juneau: GPE
# Houston: GPE
# Quito: GPE
# Nome: ORG
# Aruba: GPE
# ABNER H. DODGE: PERSON
# 44,066.12: MONEY
# R. Duke: PERSON
# the Western Hemosphere: ORG
# Culebra: FAC
# Caribbean: LOC
# Carib: ORG
# three: CARDINAL
# Berlitz: NORP
# nineteen hours: TIME
# Colombia: GPE
# Venezuelan: NORP
# Guajiro: WORK_OF_ART
# Jibaros: WORK_OF_ART
# Manaus: GPE
# Jibaro: NORP
# Rio: GPE
# Manaus: ORG
# Nixon: PERSON
# Tim Leary's: PERSON
# America: GPE
# West Point: LOC
# Peace: ORG
# three bucks: MONEY
# Leary: PERSON
# the Catholic
# Church: ORG
# Pope: PERSON
# One: CARDINAL
# that day: DATE
# Maharishi: ORG
# Dylan: PERSON
# Vatican: FAC
# Pope: PERSON
# First: ORDINAL
# Manson: ORG
# Mel Lyman: PERSON
# Avatar: PERSON
# 1965: DATE
# Oakland: GPE
# Barger: PERSON
# Rising Tide: WORK_OF_ART
# the Youth Movement: ORG
# the Sixties: DATE
# first: ORDINAL
# Greasers: ORG
# SDS: ORG
# Berkeley: ORG
# Ginsberg: PERSON
# Berkeley: GPE
# Altamont: GPE
# four years later: DATE
# Altamont: GPE
# Stanyan Street: LOC
# Flamingo: ORG
# ten-foot: QUANTITY
# that afternoon: TIME
# Safeway: ORG
# the top
# half: DATE
# Tuesday: DATE
# that morning: TIME
# Do Not Disturb: WORK_OF_ART
# Mickey Rooney: PERSON
# Benevolent Assn: ORG
# the Grange Gorman: ORG
# two: CARDINAL
# just a few
# moments: PERCENT
# every day: DATE
# first: ORDINAL
# Alice: PERSON
# Linen Service: ORG
# Alice: PERSON
# about a week: DATE
# Carson City: GPE
# Inspector Rock: ORG
# Arthur Rock: PERSON
# Inspector Rock: ORG
# a thousand dollars: MONEY
# the ninth of every month: DATE
# one: CARDINAL
# One: CARDINAL
# Dow: ORG
# midnight: TIME
# 12: CARDINAL
# the Circus - Circus: ORG
# Almost seventy-two: CARDINAL
# Alice: PERSON
# about six inches: QUANTITY
# Haight Street: FAC
# french: NORP
# Whores: NORP
# Casbah: GPE
# twenty-two: CARDINAL
# five days: DATE
# nights: TIME
# Riiiinnnnnggggggg: PERSON
# Heem: PERSON
# first: ORDINAL
# first: ORDINAL
# Mace: PERSON
# Bruce Innes: PERSON
# Circus-Circus: ORG
# 750: MONEY
# Last night: TIME
# four hundred: CARDINAL
# Bruce: PERSON
# Bruce: PERSON
# ten minutes: TIME
# the Circus-Circus: ORG
# Bruce: PERSON
# Vegas: GPE
# Cadillac: ORG
# Heavy: ORG
# hu mored: PERSON
# Vegas: GPE
# wan der: PERSON
# night: TIME
# Bruce: PERSON
# two: CARDINAL
# first: ORDINAL
# R. Duke: PERSON
# Bruce: PERSON
# IU: ORG
# American: NORP
# Bruce: PERSON
# two: CARDINAL
# Horatio Alger: PERSON
# Bruce: PERSON
# a thousand bucks: MONEY
# two: CARDINAL
# the Leopard Lounge: ORG
# two: CARDINAL
# two hours: TIME
# Boss: ORG
# Vegas: GPE
# Bruce: PERSON
# Chicago: GPE
# Several months later: DATE
# Aspen: GPE
# Bruce: PERSON
# Canadian: NORP
# evening: TIME
# the Immigration Statutes: LAW
# Bob Zimmerman: PERSON
# one: CARDINAL
# Polack: PERSON
# Polack: ORG
# Bruce Mmuttered: PERSON
# fourteen year old: DATE
# about six feet: QUANTITY
# Eight: CARDINAL
# ten: CARDINAL
# Aspen: ORG
# LasVegas: ORG
# five: CARDINAL
# Vegas: GPE
# five years: DATE
# Nixon: PERSON
# John Mitchell: PERSON
# Sheriff: ORG
# Agnew: PERSON
# 13: CARDINAL
# Soaking Sweats: PERSON
# one: CARDINAL
# Thompson: ORG
# Rolling Stone: ORG
# Mafia: ORG
# Hollywood: GPE
# one: CARDINAL
# St. Loius: GPE
# PBA: ORG
# five-dollar: MONEY
# Flamingo: ORG
# Lake Mead: LOC
# Detroit: GPE
# about fifteen years old: DATE
# Boulevard: FAC
# Sahara: LOC
# only two dollars: MONEY
# this of the morning: TIME
# first: ORDINAL
# LA: GPE
# One: CARDINAL
# Tambourine: PERSON
# Blues Again: WORK_OF_ART
# eight: CARDINAL
# two hours: TIME
# Nixon: PERSON
# Hy're yew: WORK_OF_ART
# sme: ORG
# today: DATE
# the lam
# : ORG
# Scotland Yard: ORG
# Vegas: GPE
# A thousand: CARDINAL
# three: CARDINAL
# six: CARDINAL
# The
# Airport Lounge: ORG
# Bloody Marys: GPE
# Mexsana: ORG
# today: DATE
# Las Vegas: GPE
# morning: TIME
# the Narcotics and Dangerous Drugs: ORG
# one: CARDINAL
# five or: CARDINAL
# King Marlboros: ORG
# evening: TIME
# about ten yards: QUANTITY
# Las Vegas: GPE
# Argentine: NORP
# the Naval ROTC: FAC
# Three eighths of an
# inch: CARDINAL
# about two eights more: CARDINAL
# the South China Sea: LOC
# andmany years later: DATE
# Las Vegas: GPE
# this terrible morning: TIME
# Accidental" Assault on Guam: WORK_OF_ART
# AOP)-Aboard the USS: PRODUCT
# Sept. 25)-The: DATE
# 3485: CARDINAL
# American: NORP
# today: DATE
# five: CARDINAL
# Captain: ORG
# the Heroin Police: ORG
# Hong See: ORG
# Bboor: PERSON
# 4th: ORDINAL
# Fleet
# Service: ORG
# Tom Thumb's Blues: WORK_OF_ART
# five: CARDINAL
# Pacific: LOC
# 4th Fleet Headquarters: ORG
# Navy: ORG
# New Orleans: GPE
# ney James Garrison: PERSON
# Agnew
# : PERSON
# misfits-: CARDINAL
# 14: CARDINAL
# Vegas: GPE
# Raoul Duke: PERSON
# Spe: ORG
# Los: GPE
# Angeles: GPE
# Malibu: GPE
# thousand: CARDINAL
# a few days: DATE
# Las Vegas: GPE
# the District Attorneys' Association: ORG
# about ten years: DATE
# the Drug Culture: WORK_OF_ART
# 1971: DATE
# thousands of dollars: MONEY
# LSD: PRODUCT
# over thirty: CARDINAL
# these days: DATE
# Downers: ORG
# today: DATE
# Miltown: PERSON
# skin-: CARDINAL
# 200: CARDINAL
# Seconal: ORG
# Methedrine: ORG
# 1971: DATE
# Consciousness Ex: PRODUCT
# Nixon: PERSON
# Bloody Mary: PERSON
# Denver: GPE
# the Rocky Mountains: LOC
# Doberman: GPE
# Denver: GPE
# Dobermans: NORP
# first: ORDINAL
# adn: ORG
# I.D.: LOC
# the Church of the New Truth: ORG
# seconds: TIME
# two: CARDINAL
# Marines: NORP
# the Brown Palace: FAC
# Horatio Alger
# : PERSON
#
#
# Ex Machina Entities
# Alex Garland: PERSON
# 1: CARDINAL
# OFFICE - DAY: DATE
# CALEB: ORG
# two: CARDINAL
# CALEB'S: ORG
# CALEB: ORG
# Twenty four: CARDINAL
# 2: CARDINAL
# CALEB: PERSON
# CALEB: PERSON
# CALEB'S: ORG
# CAM: PRODUCT
# CALEB: PERSON
# CALEB: PERSON
# 3: CARDINAL
# Buena: ORG
# bro: ORG
# fucking AWESOME
#
#          :o)
#
#          : ORG
# One: CARDINAL
# CALEB: ORG
# 2: CARDINAL
# 2: CARDINAL
# EXT: PRODUCT
# MOUNTAINS - DAY: DATE
# 3: CARDINAL
# 3: CARDINAL
# JAY: PERSON
# 4: CARDINAL
# CALEB: PERSON
# JAY
#           : PERSON
# Long Island: GPE
# Bateman: PERSON
# 5: CARDINAL
# JAY: PERSON
# one: CARDINAL
# a hundred miles: QUANTITY
# JAY: PERSON
# CALEB: ORG
# Long
#           Island: ORG
# a week: DATE
# Bateman: PERSON
# CALEB: PERSON
# CALEB: PERSON
# JAY: PERSON
# Alaska: GPE
# Earth: LOC
# JAY: PERSON
# the past two hours: TIME
# 6: CARDINAL
# 4: CARDINAL
# EXT: PRODUCT
# MOUNTAINS - DAY: DATE
# 5: CARDINAL
# 5: CARDINAL
# EXT: PRODUCT
# MOUNTAINS - DAY: DATE
# 6: CARDINAL
# 6: CARDINAL
# EXT: PRODUCT
# MOUNTAINS - DAY: DATE
# DAY: DATE
# 8: CARDINAL
# 8: CARDINAL
# EXT: PRODUCT
# MEADOW/LANDING SITE - DAY: ORG
# Chinese: NORP
# 9: CARDINAL
# 9: CARDINAL
# EXT: PRODUCT
# MEADOW/LANDING SITE - DAY: ORG
# CALEB: PERSON
# CALEB: PERSON
# CALEB'S: ORG
# CALEB: PERSON
# CALEB: PERSON
# 7: CARDINAL
# JAY
#                : PERSON
# JAY
#                Follow: ORG
# JAY: PERSON
# CALEB: PERSON
# 10: CARDINAL
# 10: CARDINAL
# EXT: ORG
# RIVER - DAY: ORG
# CALEB: ORG
# 11: CARDINAL
# 11: CARDINAL
# EXT: ORG
# VIEW - DAY: DATE
# 8: CARDINAL
# 12: CARDINAL
# 12: CARDINAL
# EXT: ORG
# CLEARING: ORG
# four metres: QUANTITY
# CALEB: PERSON
# one: CARDINAL
# 12A: ORG
# HOUSE: ORG
# Caleb Smith: PERSON
# DISPENSER: ORG
# 9: CARDINAL
# CALEB: PERSON
# 13: CARDINAL
# 13: CARDINAL
# HOUSE: ORG
# ROOM - DAY: DATE
# second: ORDINAL
# 13A: CARDINAL
# HOUSE: ORG
# 10: CARDINAL
# 14: CARDINAL
# 14: CARDINAL
# EXT: ORG
# GARDEN - DAY: ORG
# NATHAN BATEMAN: PERSON
# NATHAN: ORG
# CALEB: PERSON
# NATHAN
#                Caleb: ORG
# NATHAN: ORG
# Caleb Smith: PERSON
# NATHAN: ORG
# NATHAN
#                Dude: ORG
# 15: CARDINAL
# 15: CARDINAL
# HOUSE: ORG
# NATHAN: ORG
# 11: CARDINAL
# NATHAN: ORG
# this morning: TIME
# NATHAN: ORG
# NATHAN: ORG
# the next morning: TIME
# NATHAN: ORG
# CALEB: PERSON
# CALEB: PERSON
# NATHAN: ORG
# NATHAN: ORG
# 12: CARDINAL
# NATHAN
#           Party: ORG
# NATHAN: ORG
# CALEB: ORG
# Caleb: PERSON
# CALEB: PERSON
# NATHAN: ORG
# two: CARDINAL
# Caleb: ORG
# CALEB: PERSON
# CALEB: PERSON
# NATHAN: ORG
# NATHAN: ORG
# Caleb: PERSON
# 13: CARDINAL
# CALEB: PERSON
# 16: CARDINAL
# 16: CARDINAL
# EXT: ORG
# HOUSE: ORG
# CALEB: PERSON
# NATHAN
#                 Down: ORG
# 16A: CARDINAL
# RIVER - DAY: ORG
# 17: CARDINAL
# 17: CARDINAL
# HOUSE: ORG
# NATHAN: ORG
# CALEB: PERSON
# NATHAN: ORG
# first: ORDINAL
# 14: CARDINAL
# Caleb: PERSON
# 18: CARDINAL
# 18: CARDINAL
# HOUSE: ORG
# BEDROOM - DAY: DATE
# NATHAN: ORG
# CALEB: PERSON
# NATHAN
#                You: ORG
# NATHAN: ORG
# CALEB: PERSON
# NATHAN
#                : ORG
# NATHAN
#                There's: ORG
# CALEB
#                : ORG
# 15: CARDINAL
# NATHAN
#                It's: ORG
# CALEB
#                : ORG
# NATHAN
#                Caleb: ORG
# NATHAN
#                : ORG
# Moon: PERSON
# NATHAN: ORG
# first: ORDINAL
# NATHAN: ORG
# 19: CARDINAL
# HOUSE: ORG
# BEDROOM - DAY: DATE
# NATHAN'S: ORG
# 16: CARDINAL
# NATHAN: ORG
# CALEB: PERSON
# NATHAN
#             It's: ORG
# NATHAN: ORG
# NATHAN: PERSON
# next seven days: DATE
# a year or so: DATE
# NATHAN: ORG
# NATHAN: ORG
# 17: CARDINAL
# Turing Test: ORG
# CALEB: PERSON
# NATHAN: ORG
# Turing: ORG
# NATHAN: ORG
# CALEB: PERSON
# CALEB: PERSON
# NATHAN: ORG
# NATHAN: ORG
# NATHAN: ORG
# the next few days: DATE
# Turing Test: ORG
# NATHAN: ORG
# Caleb: PERSON
# 18: CARDINAL
# 20: CARDINAL
# HOUSE: ORG
# ROOM - DAY: DATE
# AVA: ORG
# Proportioned: ORG
# twenties: DATE
# five: CARDINAL
# one: CARDINAL
# one: CARDINAL
# 19: CARDINAL
# AVA: PERSON
# half: CARDINAL
# AVA: PERSON
# AVA'S: ORG
# three: CARDINAL
# the PRIVATE AREA: LOC
# the GARDEN AREA: LOC
# AVA: PERSON
# CALEB: PERSON
# CALEB: PERSON
# AVA: PERSON
# first: ORDINAL
# CALEB: PERSON
# AVA
#            Hello: ORG
# 20: CARDINAL
# AVA: PRODUCT
# Caleb: PERSON
# AVA
#           Hello: ORG
# Caleb: PERSON
# AVA: ORG
# CALEB: PERSON
# Ava: PERSON
# AVA: PRODUCT
# half: CARDINAL
# CCTV: ORG
# CALEB: PERSON
# AVA: PERSON
# AVA: ORG
# CALEB: PERSON
# AVA: PERSON
# CALEB: PERSON
# AVA: PERSON
# AVA: PRODUCT
# 21: CARDINAL
# AVA: ORG
# AVA: ORG
# AVA: ORG
# AVA: ORG
# Nathan: ORG
# AVA: ORG
# CALEB: PERSON
# AVA: ORG
# AVA: PRODUCT
# 22: CARDINAL
# AVA: PRODUCT
# AVA: PERSON
# AVA: ORG
# One: CARDINAL
# One year: DATE
# one day: DATE
# AVA: ORG
# One: CARDINAL
# AVA: PERSON
# AVA: PERSON
# first: ORDINAL
# 23: CARDINAL
# AVA: PERSON
# AVA: PRODUCT
# CALEB: PERSON
# AVA: PERSON
# CALEB: PERSON
# AVA: ORG
# AVA: PERSON
# tomorrow: DATE
# AVA: PERSON
# tomorrow: DATE
# Caleb: PERSON
# CALEB: PERSON
# 24: CARDINAL
# AVA: PERSON
# AVA
#                Good: ORG
# 21: CARDINAL
# 21: CARDINAL
# EXT: ORG
# HOUSE: ORG
# DUSK: TIME
# 22: CARDINAL
# 22: CARDINAL
# HOUSE: ORG
# DUSK: TIME
# NATHAN: ORG
# two: CARDINAL
# NATHAN: ORG
# Peroni: ORG
# NATHAN
#                So: ORG
# CALEB: PERSON
# NATHAN
#                : ORG
# CALEB
#                : ORG
# NATHAN: ORG
# NATHAN
#                `Through: ORG
# CALEB
#                : ORG
# 25: CARDINAL
# NATHAN: ORG
# Caleb: PERSON
# NATHAN: ORG
# NATHAN: ORG
# First: ORDINAL
# NATHAN: ORG
# Turing: ORG
# Ava: PERSON
# 26: CARDINAL
# NATHAN: ORG
# CALEB: PERSON
# CALEB: PERSON
# NATHAN: ORG
# CALEB: PERSON
# first: ORDINAL
# NATHAN
#            Caleb: ORG
# Ava: PERSON
# NATHAN
#                : ORG
# CALEB
#            ...: PERSON
# NATHAN: ORG
# 27: CARDINAL
# CALEB: PERSON
# CALEB: PERSON
# NATHAN
#                  : ORG
# CALEB: PERSON
# CALEB
#                  Cheers: ORG
# 23: CARDINAL
# 23: CARDINAL
# HOUSE: ORG
# 24: CARDINAL
# HOUSE: ORG
# 25: CARDINAL
# 25: CARDINAL
# HOUSE: ORG
# 26: CARDINAL
# 26: CARDINAL
# HOUSE: ORG
# 01:32: PERSON
# 28: CARDINAL
# CALEB: PERSON
# CCTV: ORG
# CALEB: PERSON
# AVA: PERSON
# AVA: PERSON
# CCTV: ORG
# AVA: PERSON
# CALEB: PERSON
# 29: CARDINAL
# CCTV: ORG
# AVA: PERSON
# CALEB: PERSON
# CALEB: PERSON
# 30: CARDINAL
# CALEB: PERSON
# 27                                                               : DATE
# 27: CARDINAL
# HOUSE: ORG
# NIGHT: TIME
# CALEB: ORG
# CALEB: PERSON
# one: CARDINAL
# 28: CARDINAL
# HOUSE: ORG
# Only one: CARDINAL
# JACKSON POLLOCK: GPE
# CALEB: PERSON
# half: CARDINAL
# CALEB: PERSON
# two: CARDINAL
# two: CARDINAL
# NATHAN: ORG
# CALEB: PERSON
# NATHAN: ORG
# Peroni: ORG
# NATHAN'S: ORG
# Ava: PERSON
# NATHAN
#           Ghostbusters: ORG
# NATHAN: ORG
# Dan Ackroyd: PERSON
# NATHAN: ORG
# 32: CARDINAL
# NATHAN
#                Ah: ORG
# NATHAN
#                : ORG
# Automatic: ORG
# CALEB
#                Sure: ORG
# NATHAN: ORG
# NATHAN
#                Sweet: ORG
# 29: CARDINAL
# 29: CARDINAL
# EXT: PRODUCT
# 30: CARDINAL
# 30: CARDINAL
# HOUSE: ORG
# BEDROOM - MORNING: TIME
# 33: CARDINAL
# Japanese: NORP
# CALEB'S: ORG
# CALEB
#                : PERSON
# JAPANESE: NORP
# 31: CARDINAL
# 31: CARDINAL
# EXT: ORG
# GARDEN/GYM AREA - DAY: ORG
# NATHAN: ORG
# NATHAN: ORG
# NATHAN
#                : ORG
# Kyoko: PERSON
# the day: DATE
# NATHAN
#                : ORG
# CALEB: PERSON
# two: CARDINAL
# NATHAN: ORG
# NATHAN
#                : ORG
# today: DATE
# 34: CARDINAL
# CALEB: PERSON
# NATHAN
#             How: ORG
# NATHAN: ORG
# NATHAN
#             : ORG
# two: CARDINAL
# NATHAN: ORG
# NATHAN: ORG
# CALEB: ORG
# night: TIME
# NATHAN: ORG
# CALEB: ORG
# 35: CARDINAL
# 32: CARDINAL
# 32: CARDINAL
# HOUSE: ORG
# ROOM - DAY: DATE
# AVA: PERSON
# AVA
#                : ORG
# AVA: PERSON
# AVA
#                : ORG
# AVA: PERSON
# AVA
#                Oh: ORG
# CALEB
#                : ORG
# AVA
#                : ORG
# every day: DATE
# AVA
#                : ORG
# AVA
#                Why: ORG
# AVA: PERSON
# 36: CARDINAL
# AVA: ORG
# AVA
#           Will: PRODUCT
# AVA: PRODUCT
# one: CARDINAL
# AVA: PERSON
# AVA: PERSON
# CALEB: PERSON
# AVA: ORG
# AVA: ORG
# AVA
#           : PRODUCT
# CALEB: PERSON
# AVA: PERSON
# 37: CARDINAL
# AVA: PERSON
# CALEB: PERSON
# Ava: PERSON
# twenty four: CARDINAL
# Nathan's: ORG
# AVA
#           Blue Book: PRODUCT
# Wittgenstein: PERSON
# ninety four percent: PERCENT
# Caleb: PERSON
# CALEB
#           Brookhaven: ORG
# Long Island: GPE
# AVA: PRODUCT
# five: CARDINAL
# five minute: TIME
# AVA: PRODUCT
# AVA: PRODUCT
# AVA: PRODUCT
# Portland: GPE
# 38: CARDINAL
# fifteen: CARDINAL
# AVA: PERSON
# CALEB: PERSON
# Nearly a year: DATE
# AVA: PERSON
# AVA: ORG
# Nathan: ORG
# CALEB: PERSON
# CALEB: PERSON
# Blue Book: WORK_OF_ART
# thirteen: CARDINAL
# AVA: ORG
# Mozart: PERSON
# CALEB: PERSON
# AVA: ORG
# Nathan: PERSON
# CALEB: PERSON
# 39: CARDINAL
# AVA
#            : ORG
# CCTV: ORG
# AVA: ORG
# CALEB: PERSON
# AVA: PERSON
# AVA: ORG
# AVA: PERSON
# AVA: PERSON
# CCTV: ORG
# 40: CARDINAL
# AVA
#            Caleb: PERSON
# CALEB: PERSON
# AVA: PERSON
# AVA: PERSON
# AVA
#            Nathan: ORG
# AVA: ORG
# CALEB: PERSON
# CALEB: PERSON
# Ava: PERSON
# AVA
#                : ORG
# AVA: PERSON
# AVA: PERSON
# 41: CARDINAL
# CCTV: ORG
# CALEB: PERSON
# AVA: ORG
# CALEB: ORG
# AVA
#                -: ORG
# Caleb: PERSON
# CALEB
#                : PERSON
# AVA: PERSON
# AVA
#                Good: ORG
# 33: CARDINAL
# 33: CARDINAL
# HOUSE: ORG
# Japanese: NORP
# KYOKO: PERSON
# 34: CARDINAL
# 34: CARDINAL
# HOUSE: ORG
# NIGHT: TIME
# CALEB: ORG
# NATHAN: ORG
# KYOKO: PERSON
# 42: CARDINAL
# NATHAN
#           Shit: ORG
# Kyoko: PERSON
# Caleb: ORG
# CALEB: PERSON
# KYOKO: PERSON
# Kyoko: PERSON
# English: LANGUAGE
# CALEB: PERSON
# KYOKO: PERSON
# HOD: ORG
# Kyoko: PERSON
# KYOKO: PERSON
# CALEB: PERSON
# 43: CARDINAL
# Kyoko: PERSON
# KYOKO: PERSON
# NATHAN: ORG
# every day: DATE
# NATHAN: ORG
# NATHAN: ORG
# CALEB: PERSON
# NATHAN: ORG
# 44: CARDINAL
# second day: DATE
# NATHAN: ORG
# CALEB: PERSON
# CCTV: ORG
# NATHAN: ORG
# one: CARDINAL
# Ava: PERSON
# today: DATE
# NATHAN: ORG
# 45: CARDINAL
# NATHAN: PERSON
# NATHAN: ORG
# CALEB: ORG
# NATHAN
#                : ORG
# CALEB: PERSON
# NATHAN: ORG
# CALEB
#                : ORG
# NATHAN
#                Nothing: ORG
# CALEB: PERSON
# NATHAN'S: ORG
# CALEB
#                No: ORG
# NATHAN'S: ORG
# 35: CARDINAL
# 35: CARDINAL
# HOUSE: ORG
# 36                                                               : DATE
# 36: CARDINAL
# HOUSE: ORG
# 46: DATE
# 37: CARDINAL
# 37: CARDINAL
# HOUSE: ORG
# AVA'S: ORG
# CALEB: PERSON
# AVA: ORG
# CCTV: ORG
# 38: CARDINAL
# 38: CARDINAL
# HOUSE: ORG
# NIGHT: TIME
# CALEB: ORG
# 47: CARDINAL
# one: CARDINAL
# 39: CARDINAL
# 39: CARDINAL
# HOUSE: ORG
# NATHAN: ORG
# KYOKO: PERSON
# a few feet: QUANTITY
# NATHAN'S: ORG
# first: ORDINAL
# a few moments: TIME
# 40: CARDINAL
# EXT: ORG
# GARDEN/GYM AREA -: ORG
# 48: CARDINAL
# 41: CARDINAL
# 41: CARDINAL
# HOUSE: ORG
# NATHAN: ORG
# KYOKO: PERSON
# KYOKO: PERSON
# 42: CARDINAL
# 42: CARDINAL
# HOUSE: ORG
# 43: CARDINAL
# 43: CARDINAL
# EXT: ORG
# NIGHT: TIME
# 44: CARDINAL
# 44: CARDINAL
# HOUSE: ORG
# UP: ORG
# AVA'S: ORG
# AVA'S: ORG
# AVA: PERSON
# 49: CARDINAL
# Ava: PERSON
# CALEB: PERSON
# 45: CARDINAL
# 45: CARDINAL
# EXT: ORG
# GARDEN - BLACK: ORG
# Ansel Adams: PERSON
# CALEB: PERSON
# AVA: ORG
# 46: CARDINAL
# 46: CARDINAL
# HOUSE: ORG
# AVA: PERSON
# AVA'S: ORG
# 47: CARDINAL
# 47: CARDINAL
# EXT: ORG
# GARDEN - MORNING: TIME
# 48: CARDINAL
# 48: CARDINAL
# EXT: ORG
# GARDEN/GYM AREA -: ORG
# MORNING: TIME
# 49: CARDINAL
# 49: CARDINAL
# HOUSE: ORG
# ROOM - DAY: DATE
# AVA: PERSON
# 50: CARDINAL
# AVA: PRODUCT
# AVA: PERSON
# AVA: PERSON
# CALEB: PERSON
# AVA: ORG
# AVA: ORG
# now: DATE
# AVA: PERSON
# AVA: PERSON
# AVA: PRODUCT
# CALEB: PERSON
# 51: CARDINAL
# AVA: PERSON
# AVA: PERSON
# CALEB: PERSON
# AVA: PRODUCT
# AVA: ORG
# AVA: ORG
# AVA: PERSON
# AVA: ORG
# CALEB: ORG
# AVA: PRODUCT
# AVA: PRODUCT
# 52: DATE
# AVA: PERSON
# AVA: PERSON
# AVA
#            : PERSON
# AVA: PERSON
# CALEB: PERSON
# the PRIVATE AREA: LOC
# First: ORDINAL
# 53: CARDINAL
# AVA: PRODUCT
# AVA: PERSON
# AVA: PERSON
# AVA: PRODUCT
# AVA: ORG
# AVA: PERSON
# CALEB: PERSON
# CALEB
#            Right: PERSON
# First: ORDINAL
# AVA: ORG
# CALEB: PERSON
# AVA: ORG
# AVA: ORG
# AVA: ORG
# AVA
#            Micro: ORG
# CALEB
#                : ORG
# AVA: ORG
# AVA: PERSON
# CALEB: PERSON
# AVA: PERSON
# 55: CARDINAL
# night: TIME
# AVA: PERSON
# CALEB: PERSON
# AVA: PERSON
# AVA: PERSON
# 50: CARDINAL
# 50: CARDINAL
# HOUSE: ORG
# ROOM - DAY: DATE
# NATHAN: ORG
# NATHAN
#                 Sure: ORG
# NATHAN: ORG
# NATHAN
#                 Actually: ORG
# 56: CARDINAL
# NATHAN: ORG
# NATHAN: ORG
# NATHAN: ORG
# CALEB: PERSON
# NATHAN: ORG
# NATHAN: ORG
# NATHAN
# : ORG
# 57: CARDINAL
# CALEB: PERSON
# NATHAN: ORG
# NATHAN: ORG
# NATHAN: ORG
# KYOKO: PERSON
# NATHAN: ORG
# Caleb: PERSON
# NATHAN: ORG
# 58: CARDINAL
# NATHAN
#                 No: ORG
# Caleb: PERSON
# NATHAN: ORG
# HOUSE: ORG
# ROOM - DAY: DATE
# CALEB: PERSON
# Pollock: PERSON
# Jackson Pollock: PERSON
# 59: CARDINAL
# NATHAN: ORG
# Jackson Pollock: PERSON
# Star Trek: WORK_OF_ART
# NATHAN: ORG
# Kirk: PERSON
# Pollock: ORG
# CALEB: PERSON
# NATHAN: ORG
# CALEB: ORG
# NATHAN: ORG
# Ava: PERSON
# 60: CARDINAL
# first: ORDINAL
# NATHAN: ORG
# 51: CARDINAL
# 51: CARDINAL
# HOUSE: ORG
# AVA: PERSON
# AVA: PERSON
# 52: CARDINAL
# HOUSE: ORG
# AVA: ORG
# 53: CARDINAL
# EXT: ORG
# RIVER - DAY: ORG
# 61: CARDINAL
# KYOKO: PERSON
# 54: CARDINAL
# 54: CARDINAL
# HOUSE: ORG
# NATHAN: ORG
# NATHAN
#                : ORG
# NATHAN
#                I: ORG
# 55: CARDINAL
# HOUSE: ORG
# DAY: DATE
# NATHAN: ORG
# 56: CARDINAL
# 56: CARDINAL
# HOUSE: ORG
# NATHAN: ORG
# CALEB: PERSON
# 62: CARDINAL
# Ava: PERSON
# NATHAN: ORG
# NATHAN: ORG
# one: CARDINAL
# NATHAN: ORG
# Blue
#           Book: ORG
# NATHAN: ORG
# NATHAN: ORG
# NATHAN: ORG
# NATHAN: ORG
# one: CARDINAL
# AVA: ORG
# 63: CARDINAL
# NATHAN: ORG
# NATHAN
#           Wetware: ORG
# NATHAN: ORG
# Blue Book: ORG
# NATHAN: ORG
# NATHAN: ORG
# CALEB: PERSON
# CALEB: PERSON
# NATHAN: ORG
# 64: CARDINAL
# NATHAN
#                Like I: ORG
# CALEB: PERSON
# Ava: PERSON
# yesterday: DATE
# NATHAN: ORG
# NATHAN: ORG
# NATHAN
#                Synthetics: ORG
# Ava: PERSON
# 57: CARDINAL
# 57: CARDINAL
# HOUSE: ORG
# ROOM - DAY: DATE
# AVA: PERSON
# AI
#                : ORG
# Mary: PERSON
# second: ORDINAL
# one day: DATE
# Mary: PERSON
# CALEB: PERSON
# Mary: PERSON
# 58: CARDINAL
# 58: CARDINAL
# HOUSE: ORG
# hundreds: CARDINAL
# thousands: CARDINAL
# 66: CARDINAL
# NATHAN'S: ORG
# One: CARDINAL
# One: CARDINAL
# NATHAN'S: ORG
# first: ORDINAL
# NATHAN: ORG
# KYOKO: PERSON
# one: CARDINAL
# AVA'S PRIVATE ROOM: ORG
# NATHAN: ORG
# 67: CARDINAL
# AVA: PERSON
# CALEB: PERSON
# NATHAN'S: ORG
# CCTV: ORG
# CALEB: PERSON
# AVA
#                     : PERSON
# AVA: PERSON
# AVA: PERSON
# AVA'S: ORG
# AVA: PERSON
# 59: CARDINAL
# 59: CARDINAL
# HOUSE: ORG
# ROOM - DAY: DATE
# AVA: PERSON
# 68: CARDINAL
# CCTV: ORG
# AVA: PERSON
# AVA: PRODUCT
# AVA: PRODUCT
# AVA: PERSON
# Nathan: ORG
# AVA: ORG
# AVA
#           Everything: ORG
# AVA: ORG
# AVA: PERSON
# AVA: PRODUCT
# 69: CARDINAL
# AVA: PERSON
# AVA
#                  : ORG
# 60: CARDINAL
# 60: CARDINAL
# HOUSE: ORG
# KYOKO: PERSON
# NATHAN'S: ORG
# CALEB: PERSON
# AVA: PERSON
# 61: CARDINAL
# 61: CARDINAL
# EXT: ORG
# RIVER - DAY: ORG
# 70: CARDINAL
# 62: CARDINAL
# 62: CARDINAL
# EXT: ORG
# WATERFALL - DAY: DATE
# NATHAN: ORG
# CALEB: PERSON
# NATHAN: ORG
# NATHAN: ORG
# 63: CARDINAL
# 63: CARDINAL
# EXT: ORG
# GLACIER - DAY: ORG
# NATHAN: ORG
# CALEB: PERSON
# NATHAN: ORG
# CALEB: ORG
# NATHAN: ORG
# CALEB: PERSON
# Turing: ORG
# NATHAN: ORG
# NATHAN: ORG
# 71: CARDINAL
# NATHAN: ORG
# Blue Book: ORG
# NATHAN: ORG
# NATHAN: ORG
# Caleb: PERSON
# 64: CARDINAL
# 64: CARDINAL
# EXT: ORG
# CLEARING: ORG
# NATHAN'S: ORG
# 72: CARDINAL
# CALEB: PERSON
# NATHAN'S: ORG
# NATHAN: ORG
# KYOKO: PERSON
# 65: CARDINAL
# HOUSE: ORG
# AVA: ORG
# CALEB: PERSON
# 66: CARDINAL
# 66: CARDINAL
# HOUSE: ORG
# AVA: PERSON
# CALEB: ORG
# AVA: PERSON
# NATHAN: ORG
# 73: CARDINAL
# NATHAN: ORG
# AVA: PERSON
# NATHAN: ORG
# AVA: ORG
# AVA: ORG
# NATHAN: ORG
# NATHAN: ORG
# AVA: PERSON
# NATHAN: ORG
# half: CARDINAL
# AVA: ORG
# 67: CARDINAL
# 67: CARDINAL
# HOUSE: ORG
# CCTV: ORG
# CALEB: PERSON
# 68: CARDINAL
# 68: CARDINAL
# HOUSE: ORG
# CALEB: PERSON
# KYOKO: PERSON
# Kyoko: PERSON
# KYOKO: PERSON
# CALEB: PERSON
# Kyoko: PERSON
# Nathan: ORG
# CALEB: PERSON
# English: LANGUAGE
# CALEB: PERSON
# 74: CARDINAL
# CALEB: PERSON
# KYOKO: PERSON
# CALEB: ORG
# CALEB: PERSON
# CALEB: PERSON
# CALEB: PERSON
# CALEB: PERSON
# NATHAN: ORG
# Lutron: ORG
# evening: TIME
# CALEB: PERSON
# KYOKO: PERSON
# 75: CARDINAL
# NATHAN: ORG
# CALEB: ORG
# NATHAN: ORG
# KYOKO: PERSON
# NATHAN: ORG
# NATHAN: ORG
# a hard day: DATE
# CALEB: PERSON
# Ava: PERSON
# NATHAN: ORG
# NATHAN: ORG
# NATHAN: ORG
# KYOKO: PERSON
# KYOKO: PERSON
# NATHAN: PERSON
# NATHAN: ORG
# NATHAN: ORG
# 69: CARDINAL
# 69: CARDINAL
# EXT: ORG
# HOUSE: ORG
# NIGHT: TIME
# half: CARDINAL
# NATHAN: ORG
# 70: CARDINAL
# 70: CARDINAL
# HOUSE: ORG
# NIGHT: TIME
# NATHAN: ORG
# NATHAN
#                  : ORG
# CALEB: PERSON
# NATHAN
#                  No: ORG
# NATHAN: ORG
# 71: CARDINAL
# 71: CARDINAL
# HOUSE: ORG
# NIGHT: TIME
# 72: CARDINAL
# 72: CARDINAL
# HOUSE: ORG
# BEDROOM - NIGHT: TIME
# NATHAN: ORG
# NATHAN: ORG
# 77: CARDINAL
# CALEB: PERSON
# Nathan: ORG
# 73: CARDINAL
# 73: CARDINAL
# HOUSE: ORG
# CALEB'S: ORG
# AVA: PERSON
# CCTV: ORG
# 74: CARDINAL
# 74: CARDINAL
# HOUSE: ORG
# BEDROOM - DAY: DATE
# 75: CARDINAL
# 75: CARDINAL
# HOUSE: ORG
# ROOM - DAY: DATE
# AVA: PERSON
# AVA
#                : ORG
# Today: DATE
# AVA
#                : ORG
# CALEB: PERSON
# AVA
#                : ORG
# CALEB
#                Shoot: ORG
# AVA: ORG
# one: CARDINAL
# CALEB
#                Red: ORG
# AVA
#                Lie: ORG
# 78: CARDINAL
# AVA
#             Lie: ORG
# a minute: TIME
# CALEB: PERSON
# CALEB: PERSON
# AVA: PERSON
# AVA: ORG
# two: CARDINAL
# AVA: PERSON
# CALEB: PERSON
# AVA: PERSON
# 79: CARDINAL
# three: CARDINAL
# CALEB: PERSON
# AVA: ORG
# CALEB: PERSON
# AVA: PERSON
# CALEB: PERSON
# AVA: PERSON
# four: CARDINAL
# AVA: PERSON
# AVA: PERSON
# 80: CARDINAL
# AVA: ORG
# CALEB: PERSON
# AVA: ORG
# AVA: ORG
# Ava -
#
#                     : PERSON
# AVA
#           Will: PRODUCT
# AVA: ORG
# Ava: PERSON
# AVA: PRODUCT
# AVA: PRODUCT
# CALEB: PERSON
# 81: CARDINAL
# AVA: PERSON
# several moments: TIME
# two: CARDINAL
# half: CARDINAL
# CALEB: PERSON
# AVA: PERSON
# AVA: PRODUCT
# AVA: PERSON
# five: CARDINAL
# AVA
#           Nathan: ORG
# 82: CARDINAL
# CALEB: PERSON
# one: CARDINAL
# AVA
#                  : ORG
# CALEB: PERSON
# 76: CARDINAL
# 76: CARDINAL
# HOUSE: ORG
# STAIRS - DAY: DATE
# 77: CARDINAL
# 77: CARDINAL
# HOUSE: ORG
# 78: CARDINAL
# EXT: ORG
# HOUSE: ORG
# DAY: DATE
# NATHAN: ORG
# CALEB: PERSON
# Peroni: ORG
# CALEB: PERSON
# Ava: PERSON
# NATHAN
#                  That's: ORG
# NATHAN: ORG
# NATHAN
#                  : ORG
# decades: DATE
# 83: CARDINAL
# CALEB: PERSON
# NATHAN: ORG
# Ava: ORG
# Ava: PERSON
# one: CARDINAL
# CALEB: PERSON
# first: ORDINAL
# NATHAN: ORG
# Ava: PERSON
# 9.6: CARDINAL
# NATHAN: ORG
# Ava: PERSON
# Kyoko: PERSON
# Kyoko: PERSON
# 84: CARDINAL
# NATHAN
#           Strip: ORG
# Kyoko: PERSON
# CALEB: PERSON
# Ava: PERSON
# CALEB: PERSON
# One day: DATE
# Africa: LOC
# CALEB
#
#                       NATHAN: ORG
# NATHAN: ORG
# Oppenheimer: ORG
# NATHAN
#               : ORG
# NATHAN: ORG
# 85: CARDINAL
# NATHAN
#                 Sure: ORG
# 79: CARDINAL
# 79: CARDINAL
# HOUSE: ORG
# AVA: ORG
# AVA: PERSON
# AVA
#                 Caleb: ORG
# AVA: PERSON
# KYOKO: PERSON
# two: CARDINAL
# AVA: PERSON
# 80: CARDINAL
# 80: CARDINAL
# EXT: ORG
# MEADOW - NIGHT: PRODUCT
# 86: CARDINAL
# 81: CARDINAL
# 81: CARDINAL
# HOUSE: ORG
# ROOM - NIGHT: TIME
# UP: GPE
# NATHAN: PERSON
# O.S.: PERSON
# Promethean: ORG
# The Bhagavad Gita: WORK_OF_ART
# CALEB'S: ORG
# NATHAN: ORG
# a couple of moments: TIME
# CALEB: PERSON
# NATHAN: ORG
# NATHAN'S: ORG
# 82: CARDINAL
# 82: CARDINAL
# HOUSE: ORG
# NATHAN'S: ORG
# CALEB: PERSON
# NATHAN'S: ORG
# CCTV: ORG
# 83: CARDINAL
# 83: CARDINAL
# HOUSE: ORG
# NIGHT: TIME
# CALEB: ORG
# NATHAN'S: ORG
# 87: CARDINAL
# 84: CARDINAL
# 84: CARDINAL
# HOUSE: ORG
# NATHAN: ORG
# 85: CARDINAL
# 85: CARDINAL
# HOUSE: ORG
# NATHAN'S: ORG
# JASMINE: ORG
# KATYA: PERSON
# AMBER: ORG
# KYOKO: PERSON
# AVA: ORG
# 86: CARDINAL
# 86: CARDINAL
# HOUSE: ORG
# NATHAN: ORG
# 88: CARDINAL
# 87: CARDINAL
# HOUSE: ORG
# NIGHT: TIME
# LILY'S: ORG
# one: CARDINAL
# CCTV: ORG
# AVA: PERSON
# NATHAN: ORG
# KATYA: PERSON
# KATYA: ORG
# NATHAN: ORG
# NATHAN: ORG
# KATYA: PERSON
# NATHAN: ORG
# Asian: NORP
# 89: CARDINAL
# One: CARDINAL
# NATHAN: ORG
# 88: CARDINAL
# HOUSE: ORG
# NATHAN: ORG
# HOUSE: ORG
# 89: CARDINAL
# 90: CARDINAL
# HOUSE: ORG
# BEDROOM - NIGHT: TIME
# NATHAN'S: ORG
# KYOKO: PERSON
# NATHAN'S: ORG
# CALEB: PERSON
# first: ORDINAL
# 90: CARDINAL
# KYOKO: PERSON
# 91: CARDINAL
# 91: CARDINAL
# HOUSE: ORG
# NIGHT: TIME
# 92: CARDINAL
# 92: CARDINAL
# HOUSE: ORG
# BEDROOM - NIGHT: TIME
# KYOKO: PERSON
# KYOKO: PERSON
# KYOKO: PERSON
# 93: CARDINAL
# 93: CARDINAL
# HOUSE: ORG
# CALEB, NATHAN
#      : ORG
# CCTV: ORG
# 91: CARDINAL
# 94: CARDINAL
# HOUSE: ORG
# BEDROOM - NIGHT: TIME
# KYOKO: PERSON
# 95: CARDINAL
# 95: CARDINAL
# HOUSE: ORG
# NATHAN: ORG
# Nathan?: ORG
# NATHAN
#                  : ORG
# NATHAN: ORG
# 92: CARDINAL
# 96: CARDINAL
# HOUSE: ORG
# AVA: PERSON
# KYOKO: PERSON
# 97: CARDINAL
# 97: CARDINAL
# HOUSE: ORG
# KYOKO: PERSON
# 93: CARDINAL
# CALEB: PERSON
# 98: CARDINAL
# 98: CARDINAL
# HOUSE: ORG
# NATHAN'S: ORG
# CALEB'S: ORG
# CALEB: PERSON
# two: CARDINAL
# KYOKO: PERSON
# 94: CARDINAL
# 99: CARDINAL
# 99: CARDINAL
# EXT: ORG
# GARDEN - DAY: DATE
# NATHAN'S: ORG
# 100: CARDINAL
# 100: CARDINAL
# GARDEN/GYM AREA - DAY: ORG
# 101: CARDINAL
# 101: CARDINAL
# HOUSE: ORG
# BEDROOM - DAY: DATE
# 102: CARDINAL
# 102: CARDINAL
# HOUSE: ORG
# ROOM - DAY: DATE
# AVA'S: ORG
# AVA: ORG
# yesterday: DATE
# afternoon: TIME
# all last night: TIME
# AVA: PERSON
# AVA: PERSON
# 95: CARDINAL
# AVA: PERSON
# CALEB: PERSON
# Nathan: ORG
# AVA: PRODUCT
# Caleb: PERSON
# tonight: TIME
# AVA: ORG
# one: CARDINAL
# ten o'clock tonight: TIME
# 96: CARDINAL
# AVA
#                  : ORG
# Twenty six hours: TIME
# CALEB: PERSON
# AVA: PERSON
# CALEB: PERSON
# AVA
#                  Caleb: ORG
# AVA: PERSON
# 103: CARDINAL
# 103: CARDINAL
# GARDEN/GYM AREA - DAY: ORG
# 104: CARDINAL
# MOUNTAINS - DAY: DATE
# 105: CARDINAL
# 105: CARDINAL
# HOUSE: ORG
# ROOM - DAY: DATE
# KYOKO: PERSON
# CALEB: PERSON
# 97: CARDINAL
# NATHAN: ORG
# tomorrow: DATE
# morning: TIME
# Eight AM: TIME
# CALEB: PERSON
# a whole week: DATE
# NATHAN: ORG
# CALEB: PERSON
# NATHAN: ORG
# NATHAN: ORG
# CALEB: PERSON
# two: CARDINAL
# CALEB: PERSON
# 98: CARDINAL
# NATHAN: ORG
# NATHAN: ORG
# NATHAN: ORG
# NATHAN: ORG
# NATHAN: ORG
# this morning: TIME
# NATHAN'S: ORG
# CALEB: PERSON
# NATHAN: ORG
# 99: CARDINAL
# NATHAN: PERSON
# Ava: PERSON
# CALEB: PERSON
# NATHAN: ORG
# NATHAN: ORG
# NATHAN: ORG
# Ava: PERSON
# third: ORDINAL
# CALEB
#           Pretending.: ORG
# 100: CARDINAL
# NATHAN: ORG
# CALEB: PERSON
# NATHAN: ORG
# NATHAN: ORG
# CALEB: PERSON
# NATHAN: ORG
# NATHAN: ORG
# this morning: TIME
# NATHAN: ORG
# CALEB: ORG
# NATHAN: ORG
# NATHAN: ORG
# 101: CARDINAL
# 106: CARDINAL
# 106: CARDINAL
# HOUSE: ORG
# CALEB: PERSON
# CALEB: PERSON
# two nights before: DATE
# AVA'S: ORG
# first: ORDINAL
# AVA: ORG
# AVA: PERSON
# NATHAN: ORG
# AVA: PERSON
# NATHAN: ORG
# two: CARDINAL
# CALEB: PERSON
# two: CARDINAL
# NATHAN: ORG
# AVA
#                   : WORK_OF_ART
# NATHAN: ORG
# two: CARDINAL
# AVA: PERSON
# NATHAN: ORG
# 102: CARDINAL
# 107: CARDINAL
# 107: CARDINAL
# HOUSE: ORG
# CALEB: ORG
# NATHAN
#                    You: ORG
# NATHAN
#                    Misdirection: ORG
# NATHAN: ORG
# NATHAN: ORG
# NATHAN: ORG
# AVA'S: ORG
# two: CARDINAL
# a few moments: TIME
# 103: CARDINAL
# NATHAN: ORG
# tonight: TIME
# AVA
#               : PRODUCT
# one: CARDINAL
# ten o'clock tonight: TIME
# CALEB: PERSON
# NATHAN: ORG
# CALEB: PERSON
# Ava: PERSON
# self-: DATE
# CALEB: PERSON
# NATHAN: ORG
# NATHAN
#            : ORG
# NATHAN
#            They: ORG
# NATHAN: ORG
# CALEB: PERSON
# NATHAN
#            Shit: ORG
# NATHAN: ORG
# 105: CARDINAL
# one: CARDINAL
# Ava: PERSON
# 108: CARDINAL
# 108: CARDINAL
# GARDEN - NIGHT: FAC
# 109: CARDINAL
# 109: CARDINAL
# HOUSE: ORG
# AVA'S: ORG
# 110: CARDINAL
# 110: CARDINAL
# HOUSE: ORG
# NATHAN: ORG
# NATHAN: ORG
# ten
#                 o'clock: DATE
# CALEB: ORG
# Ava: PERSON
# CALEB: PERSON
# 106: CARDINAL
# NATHAN: ORG
# CALEB: PERSON
# NATHAN: ORG
# CALEB: PERSON
# yesterday: DATE
# NATHAN: ORG
# CCTV: ORG
# AVA'S: ORG
# 107: CARDINAL
# NATHAN: ORG
# CALEB: PERSON
# NATHAN: ORG
# A couple of yards: QUANTITY
# 111: CARDINAL
# HOUSE: ORG
# NATHAN: ORG
# AVA: PERSON
# KYOKO: PERSON
# KYOKO'S: PERSON
# AVA'S: ORG
# KYOKO: PERSON
# two: CARDINAL
# NATHAN'S: ORG
# NATHAN: ORG
# NATHAN'S: ORG
# NATHAN
#                 Ava: ORG
# Ava -: PERSON
# 108: CARDINAL
# UP: CARDINAL
# NATHAN'S: ORG
# NATHAN: ORG
# UP: CARDINAL
# AVA: ORG
# NATHAN'S: ORG
# 112: CARDINAL
# 112: CARDINAL
# EXT: PRODUCT
# GARDEN - NIGHT: ORG
# Moon: PERSON
# 112A: CARDINAL
# 112A
#        INT: PRODUCT
# HOUSE: ORG
# NATHAN: ORG
# first: ORDINAL
# AVA: PERSON
# NATHAN'S: ORG
# AVA: ORG
# AVA: PERSON
# half: CARDINAL
# 112B: CARDINAL
# 112B: PRODUCT
# HOUSE: ORG
# 112C: CARDINAL
# 112C: CARDINAL
# HOUSE: ORG
# KYOKO: PERSON
# NATHAN: ORG
# NATHAN: ORG
# KYOKO: PERSON
# first: ORDINAL
# NATHAN
#                    Aah: ORG
# ridge: ORG
# KYOKO: PERSON
# KYOKO: PERSON
# NATHAN: ORG
# KYOKO -
#
#       : PERSON
# AVA: PERSON
# NATHAN: ORG
# AVA: PERSON
# AVA: ORG
# KYOKO: PERSON
# NATHAN: ORG
# a few moments: TIME
# NATHAN: ORG
# 113: CARDINAL
# 113: CARDINAL
# HOUSE: ORG
# CALEB: PERSON
# CCTV: ORG
# NATHAN'S: ORG
# 111: CARDINAL
# NATHAN'S: ORG
# AVA: PERSON
# NATHAN'S: ORG
# AVA: PERSON
# CALEB: PERSON
# AVA
#                  : ORG
# AVA: PERSON
# CCTV: ORG
# AVA: PERSON
# NATHAN'S: ORG
# 114: CARDINAL
# 114: CARDINAL
# HOUSE: ORG
# BEDROOM - NIGHT: TIME
# NATHAN'S: ORG
# AVA: ORG
# 112: CARDINAL
# 115: CARDINAL
# 115: CARDINAL
# HOUSE: ORG
# CALEB: PERSON
# AVA: PERSON
# First: ORDINAL
# Nathan: ORG
# 116: CARDINAL
# 116: CARDINAL
# DAWN: TIME
# First: ORDINAL
# 117: CARDINAL
# 117: CARDINAL
# HOUSE: ORG
# AVA: PERSON
# AVA: PERSON
# 118: CARDINAL
# 118: CARDINAL
# HOUSE: ORG
# AVA: PERSON
# CALEB
#                 Ava: PERSON
# Ava: PERSON
# AVA: PERSON
# 113: CARDINAL
# 118A: CARDINAL
# 118A: CARDINAL
# HOUSE: ORG
# AVA: PERSON
# KYOKO: PERSON
# NATHAN'S: ORG
# NATHAN'S: ORG
# 118AA                                                              118AA: WORK_OF_ART
# HOUSE: ORG
# AVA: PERSON
# 118B: ORG
# EXT: ORG
# first: ORDINAL
# 118C: PRODUCT
# HOUSE: ORG
# CALEB: PERSON
# NATHAN'S: ORG
# 119: CARDINAL
# 119: CARDINAL
# EXT: PRODUCT
# GARDEN - DAWN: FAC
# Ava: PERSON
# AVA: PERSON
# 114: CARDINAL
# 120: CARDINAL
# 120: CARDINAL
# HOUSE: ORG
# Ava: PERSON
# AVA: WORK_OF_ART
# HOUSE: ORG
# NATHAN'S: ORG
# KYOKO: PERSON
# 121: CARDINAL
# 121: CARDINAL
# EXT: PRODUCT
# RIVER - DAWN: PRODUCT
# AVA: PERSON
# 122: CARDINAL
# 122: CARDINAL
# EXT: PRODUCT
# MOUNTAINS - DAY: ORG
# 123: CARDINAL
# 123: CARDINAL
# - DAY: DATE
# 124: CARDINAL
# 124: CARDINAL
# EXT: PRODUCT
# MEADOW/LANDING SITE - DAY: ORG
# a few metres: QUANTITY
# AVA: PERSON
# early twenties: DATE
# AVA: PERSON
# 115: CARDINAL
# 125: CARDINAL
# 125: CARDINAL
# EXT: PRODUCT
# MEADOW/LANDING SITE - DAY: ORG
# PILOT: ORG
# AVA: PERSON
# 126: CARDINAL
# 126: CARDINAL
# MEADOW - DAY: ORG
# AVA: ORG
# 127: CARDINAL
# 127: CARDINAL
# HOUSE: ORG
# 116: CARDINAL
# 128: CARDINAL
# EXT: ORG
# North America: LOC
# AVA: PERSON
#
#
# Giving Tree Entities
# one day: DATE
# one day: DATE

# %%
"""Part 5 b
Produce a bar plot for each document that includes the count for the 20 most common named entities (by name)."""

# Get a list of each entity occurence by name for each document
fear_text_ent_list = [entity.text for entity in fear_doc.ents]
machina_text_ent_list = [entity.text for entity in machina_doc.ents]
tree_text_ent_list = [entity.text for entity in tree_doc.ents]

# Use a Counter on each list
fear_top20_ents = Counter(fear_text_ent_list).most_common()[:20]
machina_top20_ents = Counter(machina_text_ent_list).most_common()[:20]
tree_top20_ents = Counter(tree_text_ent_list).most_common()[:20]

# Get dataframes of the sorted counters
fear_top20_df = pd.DataFrame(fear_top20_ents, columns=['entity', 'count'])
machina_top20_df = pd.DataFrame(machina_top20_ents, columns=['entity', 'count'])
tree_top20_df = pd.DataFrame(tree_top20_ents, columns=['entity', 'count'])

# Plot and show the bar graphs
fear_top20_df.plot.bar(x='entity', y='count', legend=False)
plt.title("Fear and Loathing Entity Frequencies")
plt.gcf().tight_layout()

machina_top20_df.plot.bar(x='entity', y='count', legend=False)
plt.title("Ex Machina Entity Frequencies")
plt.gcf().tight_layout()

# Note the giving tree is short and only has 1 entity
# that occurs twice
tree_top20_df.plot.bar(x='entity', y='count', legend=False)
plt.title("Giving Tree Entity Frequencies")
plt.gcf().tight_layout()

# %%
"""Part 5 c
Produce a second bar plot per document based on the counts of every named entity type (PERSON, ORG, etc.)"""

# Get a list of each entity's label for each document
fear_lbl_ent_list = [entity.label_ for entity in fear_doc.ents]
machina_lbl_ent_list = [entity.label_ for entity in machina_doc.ents]
tree_lbl_ent_list = [entity.label_ for entity in tree_doc.ents]

# Use a Counter on each list
fear_lbl_ents = Counter(fear_lbl_ent_list).most_common()
machina_lbl_ents = Counter(machina_lbl_ent_list).most_common()
tree_lbl_ents = Counter(tree_lbl_ent_list).most_common()

# Get dataframes of the sorted counters
fear_lbl_df = pd.DataFrame(fear_lbl_ents, columns=['entity type', 'count'])
machina_lbl_df = pd.DataFrame(machina_lbl_ents, columns=['entity type', 'count'])
tree_lbl_df = pd.DataFrame(tree_lbl_ents, columns=['entity type', 'count'])

# Plot and show the bar graphs
fear_lbl_df.plot.bar(x='entity type', y='count', legend=False)
plt.title("Fear and Loathing Label Frequencies")
plt.gcf().tight_layout()

machina_lbl_df.plot.bar(x='entity type', y='count', legend=False)
plt.title("Ex Machina Label Frequencies")
plt.gcf().tight_layout()

# Note the giving tree is short and only has 1 entity
# that occurs twice
tree_lbl_df.plot.bar(x='entity type', y='count', legend=False)
plt.title("Giving Tree Label Frequencies")
plt.gcf().tight_layout()

# %%
"""Part 5 d
Do you notice any meaningful differences (or similarities) among the documents wrt to these plots? If so, explain what they are."""

# This will be in the report
# Out:
# 'Part 5 d\nDo you notice any meaningful differences (or similarities) among the documents wrt to these plots? If so, explain what they are.'
